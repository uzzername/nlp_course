# %% [markdown]
# ### N-gram language models or how to write scientific papers (4 pts)
#
# We shall train our language model on a corpora of [ArXiv](http://arxiv.org/) articles and see if we can generate a new one!
#
# ![img](https://media.npr.org/assets/img/2013/12/10/istock-18586699-monkey-computer_brick-16e5064d3378a14e0e4c2da08857efe03c04695e-s800-c85.jpg)
#
# _data by neelshah18 from [here](https://www.kaggle.com/neelshah18/arxivdataset/)_
#
# _Disclaimer: this has nothing to do with actual science. But it's fun, so who cares?!_

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Alternative manual download link: https://yadi.sk/d/_nGyU2IajjR9-w
# !wget "https://www.dropbox.com/s/99az9n1b57qkd9j/arxivData.json.tar.gz?dl=1" -O arxivData.json.tar.gz
# !tar -xvzf arxivData.json.tar.gz
data = pd.read_json("./arxivData.json")
data.sample(n=5)
# Out:
#                                                   author  day            id  \
# 30802  [{'name': 'Bo Liu'}, {'name': 'Mandar Dixit'},...   13  1801.04356v2
# 35030  [{'name': 'Alyssa Adams'}, {'name': 'Hector Ze...   23  1512.07450v3
# 16672       [{'name': 'Xinyu Hua'}, {'name': 'Lu Wang'}]   28  1705.00045v2
# 38762  [{'name': 'H. R. Chennamma'}, {'name': 'Lalith...   31   1210.8318v1
# 1710   [{'name': 'Luke Vilnis'}, {'name': 'David Bela...    4  1503.01397v3
#
#                                                     link  month  \
# 30802  [{'rel': 'alternate', 'href': 'http://arxiv.or...      1
# 35030  [{'rel': 'alternate', 'href': 'http://arxiv.or...     12
# 16672  [{'rel': 'alternate', 'href': 'http://arxiv.or...      4
# 38762  [{'rel': 'alternate', 'href': 'http://arxiv.or...     10
# 1710   [{'rel': 'alternate', 'href': 'http://arxiv.or...      3
#
#                                                  summary  \
# 30802  The problem of data augmentation in feature sp...
# 35030  Can we quantify the change of complexity throu...
# 16672  We investigate the problem of sentence-level s...
# 38762  Editing on digital images is ubiquitous. Ident...
# 1710   Many inference problems in structured predicti...
#
#                                                      tag  \
# 30802  [{'term': 'cs.CV', 'scheme': 'http://arxiv.org...
# 35030  [{'term': 'cs.NE', 'scheme': 'http://arxiv.org...
# 16672  [{'term': 'cs.CL', 'scheme': 'http://arxiv.org...
# 38762  [{'term': 'cs.CV', 'scheme': 'http://arxiv.org...
# 1710   [{'term': 'stat.ML', 'scheme': 'http://arxiv.o...
#
#                                                    title  year
# 30802       Feature Space Transfer for Data Augmentation  2018
# 35030       Interacting Behavior and Emerging Complexity  2015
# 16672  Understanding and Detecting Supporting Argumen...  2017
# 38762  Mugshot Identification from Manipulated Facial...  2012
# 1710           Bethe Projections for Non-Local Inference  2015

# %%
# assemble lines: concatenate title and description
lines = data.apply(lambda row: row['title'] + ' ; ' + row['summary'].replace("\n", ' '), axis=1).tolist()

sorted(lines, key=len)[:3]
# Out:
# ['Differential Contrastive Divergence ; This paper has been retracted.',
#  'What Does Artificial Life Tell Us About Death? ; Short philosophical essay',
#  'P=NP ; We claim to resolve the P=?NP problem via a formal argument for P=NP.']

# %% [markdown]
# ### Tokenization
#
# You know the dril. The data is messy. Go clean the data. Use WordPunctTokenizer or something.

# %%
# Task: convert lines (in-place) into strings of space-separated tokens. Import & use WordPunctTokenizer
from nltk.tokenize import WordPunctTokenizer
tokenizer = WordPunctTokenizer()

lines = [" ".join(tokenizer.tokenize(line.lower())) for line in lines]

# %%
assert sorted(lines, key=len)[0] == \
    'differential contrastive divergence ; this paper has been retracted .'
assert sorted(lines, key=len)[2] == \
    'p = np ; we claim to resolve the p =? np problem via a formal argument for p = np .'

# %% [markdown]
# ### N-Gram Language Model (1point)
#
# A language model is a probabilistic model that estimates text probability: the joint probability of all tokens $w_t$ in text $X$: $P(X) = P(w_1, \dots, w_T)$.
#
# It can do so by following the chain rule:
# $$P(w_1, \dots, w_T) = P(w_1)P(w_2 \mid w_1)\dots P(w_T \mid w_1, \dots, w_{T-1}).$$
#
# The problem with such approach is that the final term $P(w_T \mid w_1, \dots, w_{T-1})$ depends on $n-1$ previous words. This probability is impractical to estimate for long texts, e.g. $T = 1000$.
#
# One popular approximation is to assume that next word only depends on a finite amount of previous words:
#
# $$P(w_t \mid w_1, \dots, w_{t - 1}) = P(w_t \mid w_{t - n + 1}, \dots, w_{t - 1})$$
#
# Such model is called __n-gram language model__ where n is a parameter. For example, in 3-gram language model, each word only depends on 2 previous words.
#
# $$
#     P(w_1, \dots, w_n) = \prod_t P(w_t \mid w_{t - n + 1}, \dots, w_{t - 1}).
# $$
#
# You can also sometimes see such approximation under the name of _n-th order markov assumption_.

# %% [markdown]
# The first stage to building such a model is counting all word occurences given N-1 previous words

# %%
from tqdm import tqdm
from collections import defaultdict, Counter, deque

# %%
from tqdm import tqdm
from collections import defaultdict, Counter, deque

# special tokens: 
# - `UNK` represents absent tokens, 
# - `EOS` is a special token after the end of sequence

UNK, EOS = "_UNK_", "_EOS_"

class NgramException(Exception):
    pass

def count_ngrams(lines, n):
    """
    Count how many times each word occured after (n - 1) previous words
    :param lines: an iterable of strings with space-separated tokens
    :returns: a dictionary { tuple(prefix_tokens): {next_token_1: count_1, next_token_2: count_2}}

    When building counts, please consider the following two edge cases:
    - if prefix is shorter than (n - 1) tokens, it should be padded with UNK. For n=3,
      empty prefix: "" -> (UNK, UNK)
      short prefix: "the" -> (UNK, the)
      long prefix: "the new approach" -> (new, approach)
    - you should add a special token, EOS, at the end of each sequence
      "... with deep neural networks ." -> (..., with, deep, neural, networks, ., EOS)
      count the probability of this token just like all others.
    """
    counts = defaultdict(Counter)
    # counts[(word1, word2)][word3] = how many times word3 occured after (word1, word2)
    for line in tqdm(lines):
        prefix = deque(maxlen=n-1)
        for num, next_token in enumerate(line.split(" ") + [EOS]):
            if num <= n - 1:
                counts[(UNK,)*(n-1 - num) + tuple(prefix)][next_token] += 1
            else:
                counts[tuple(prefix)][next_token] += 1
            prefix.append(next_token)
    return counts

# %%
# let's test it
dummy_lines = sorted(lines, key=len)[:100]
dummy_counts = count_ngrams(dummy_lines, n=3)
assert set(map(len, dummy_counts.keys())) == {2}, "please only count {n-1}-grams"
assert len(dummy_counts[('_UNK_', '_UNK_')]) == 78
assert dummy_counts['_UNK_', 'a']['note'] == 3
assert dummy_counts['p', '=']['np'] == 2
assert dummy_counts['author', '.']['_EOS_'] == 1
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 37705.00it/s]

# %% [markdown]
# Once we can count N-grams, we can build a probabilistic language model.
# The simplest way to compute probabilities is in proporiton to counts:
#
# $$ P(w_t | prefix) = { Count(prefix, w_t) \over \sum_{\hat w} Count(prefix, \hat w) } $$

# %%
from copy import deepcopy

# %%
class NGramLanguageModel:    
    def __init__(self, lines, n):
        """ 
        Train a simple count-based language model: 
        compute probabilities P(w_t | prefix) given ngram counts
        
        :param n: computes probability of next token given (n - 1) previous words
        :param lines: an iterable of strings with space-separated tokens
        """
        assert n >= 1
        self.n = n
    
        counts = count_ngrams(lines, self.n)
        
        # compute token proabilities given counts
        self.probs = deepcopy(counts)#defaultdict(Counter)
        # probs[(word1, word2)][word3] = P(word3 | word1, word2)
        
        # populate self.probs with actual probabilities
        for key, value in self.probs.items():
            _sum = sum(value.values())
            self.probs[key] = {_key: _value / _sum for _key, _value in value.items()}


            
    def get_possible_next_tokens(self, prefix):
        """
        :param prefix: string with space-separated prefix tokens
        :returns: a dictionary {token : it's probability} for all tokens with positive probabilities
        """
        prefix = prefix.split()
        prefix = prefix[max(0, len(prefix) - self.n + 1):]
        prefix = [ UNK ] * (self.n - 1 - len(prefix)) + prefix
        return self.probs[tuple(prefix)]
    
    def get_next_token_prob(self, prefix, next_token):
        """
        :param prefix: string with space-separated prefix tokens
        :param next_token: the next token to predict probability for
        :returns: P(next_token|prefix) a single number, 0 <= P <= 1
        """
        return self.get_possible_next_tokens(prefix).get(next_token, 0)

# %% [markdown]
# Let's test it!

# %%
dummy_lm = NGramLanguageModel(dummy_lines, n=3)

p_initial = dummy_lm.get_possible_next_tokens('') # '' -> ['_UNK_', '_UNK_']
assert np.allclose(p_initial['learning'], 0.02)
assert np.allclose(p_initial['a'], 0.13)
assert np.allclose(p_initial.get('meow', 0), 0)
assert np.allclose(sum(p_initial.values()), 1)

p_a = dummy_lm.get_possible_next_tokens('a') # '' -> ['_UNK_', 'a']
assert np.allclose(p_a['machine'], 0.15384615)
assert np.allclose(p_a['note'], 0.23076923)
assert np.allclose(p_a.get('the', 0), 0)
assert np.allclose(sum(p_a.values()), 1)

assert np.allclose(dummy_lm.get_possible_next_tokens('a note')['on'], 1)
assert dummy_lm.get_possible_next_tokens('a machine') == \
    dummy_lm.get_possible_next_tokens("there have always been ghosts in a machine"), \
    "your 3-gram model should only depend on 2 previous words"
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 1019.10it/s]

# %% [markdown]
# Now that you've got a working n-gram language model, let's see what sequences it can generate. But first, let's train it on the whole dataset.

# %%
lm = NGramLanguageModel(lines, n=3)
# Out:
# 100%|██████████| 41000/41000 [00:06<00:00, 6146.13it/s]

# %% [markdown]
# The process of generating sequences is... well, it's sequential. You maintain a list of tokens and iteratively add next token by sampling with probabilities.
#
# $ X = [] $
#
# __forever:__
# * $w_{next} \sim P(w_{next} | X)$
# * $X = concat(X, w_{next})$
#
#
# Instead of sampling with probabilities, one can also try always taking most likely token, sampling among top-K most likely tokens or sampling with temperature. In the latter case (temperature), one samples from
#
# $$w_{next} \sim {P(w_{next} | X) ^ {1 / \tau} \over \sum_{\hat w} P(\hat w | X) ^ {1 / \tau}}$$
#
# Where $\tau > 0$ is model temperature. If $\tau << 1$, more likely tokens will be sampled with even higher probability while less likely tokens will vanish.

# %%
lm.get_possible_next_tokens('a note')
# Out:
# {'on': 0.9285714285714286,
#  '-': 0.023809523809523808,
#  'about': 0.023809523809523808,
#  'at': 0.023809523809523808}

# %%
sum(map(lambda x: x+1, [1, 2, 3]))
# Out:
# 9

# %%
def get_next_token(lm, prefix, temperature=1.0):
    """
    return next token after prefix;
    :param temperature: samples proportionally to lm probabilities ^ (1 / temperature)
        if temperature == 0, always takes most likely token. Break ties arbitrarily.
    """
    probs = lm.get_possible_next_tokens(prefix)
    if temperature == 0:
        return max(list(probs.items()), key=lambda x: x[1])[0]
    denominator = sum(map(lambda x: x**(1/temperature), probs.values()))
    new_probs = {key: value**(1/temperature) / denominator for key, value in probs.items()}
    return np.random.choice(a=list(new_probs.keys()), p=list(new_probs.values()))

# %%
from collections import Counter
test_freqs = Counter([get_next_token(lm, 'there have') for _ in range(10000)])
assert 250 < test_freqs['not'] < 450
assert 8500 < test_freqs['been'] < 9500
assert 1 < test_freqs['lately'] < 200

test_freqs = Counter([get_next_token(lm, 'deep', temperature=1.0) for _ in range(10000)])
assert 1500 < test_freqs['learning'] < 3000
test_freqs = Counter([get_next_token(lm, 'deep', temperature=0.5) for _ in range(10000)])
assert 8000 < test_freqs['learning'] < 9000
test_freqs = Counter([get_next_token(lm, 'deep', temperature=0.0) for _ in range(10000)])
assert test_freqs['learning'] == 10000

print("Looks nice!")
# Out:
# Looks nice!

# %% [markdown]
# Let's have fun with this model

# %%
prefix = 'make it'

for i in range(100):
    prefix += ' ' + get_next_token(lm, prefix)
    if prefix.endswith(EOS) or len(lm.get_possible_next_tokens(prefix)) == 0:
        break
        
print(prefix)
# Out:
# make it faster , simpler domains to act or other types of weak multi - layer scrns can decompose an image . a promising class of erm principle ). we use data external to a given viewpoint . our experiments confirm the high accuracy above 95 %, which outperforms many other datasets and applications ; we investigate the idea that many features leads to proof number search , by jointly modeling embedding and detection algorithms and source modalities , which may require multiple rounds , almost all existing solvers are numerically robust . empirical evaluation , based on a mobile device users

# %%
prefix = 'we propose' # <- more of your ideas

for i in range(100):
    prefix += ' ' + get_next_token(lm, prefix, temperature=0.5)
    if prefix.endswith(EOS) or len(lm.get_possible_next_tokens(prefix)) == 0:
        break
        
print(prefix)
# Out:
# we propose a novel approach for the case of a set of the signal . we show that the proposed method is applied to the state - of - the - art . _EOS_

# %% [markdown]
# __More in the homework:__ nucleus sampling, top-k sampling, beam search(not for the faint of heart).

# %% [markdown]
# ### Evaluating language models: perplexity (1point)
#
# Perplexity is a measure of how well your model approximates the true probability distribution behind the data. __Smaller perplexity = better model__.
#
# To compute perplexity on one sentence, use:
# $$
#     {\mathbb{P}}(w_1 \dots w_N) = P(w_1, \dots, w_N)^{-\frac1N} = \left( \prod_t P(w_t \mid w_{t - n}, \dots, w_{t - 1})\right)^{-\frac1N},
# $$
#
#
# On the corpora level, perplexity is a product of probabilities of all tokens in all sentences to the power of $1/N$, where $N$ is __total length (in tokens) of all sentences__ in corpora.
#
# This number can quickly get too small for float32/float64 precision, so we recommend you to first compute log-perplexity (from log-probabilities) and then take the exponent.

# %%
def perplexity(lm, lines, min_logprob=np.log(10 ** -50.)):
    """
    :param lines: a list of strings with space-separated tokens
    :param min_logprob: if log(P(w | ...)) is smaller than min_logprop, set it equal to min_logrob
    :returns: corpora-level perplexity - a single scalar number from the formula above
    
    Note: do not forget to compute P(w_first | empty) and P(eos | full_sequence)
    
    PLEASE USE lm.get_next_token_prob and NOT lm.get_possible_next_tokens
    """
    probs = []
    for line in lines:
        _prefix = deque(maxlen=lm.n - 1)
        for token in line.split(" ") + [EOS]:
            prob = lm.get_next_token_prob(" ".join(_prefix), token)
            prob = max(np.log(prob), min_logprob)
            probs.append(prob)
            _prefix.append(token)

    log_perplexity = np.sum(probs)*(-1/len(probs))
    return np.e**log_perplexity

# %%
lm1 = NGramLanguageModel(dummy_lines, n=1)
lm3 = NGramLanguageModel(dummy_lines, n=3)
lm10 = NGramLanguageModel(dummy_lines, n=10)

ppx1 = perplexity(lm1, dummy_lines)
ppx3 = perplexity(lm3, dummy_lines)
ppx10 = perplexity(lm10, dummy_lines)
ppx_missing = perplexity(lm3, ['the jabberwock , with eyes of flame , '])  # thanks, L. Carrol

print("Perplexities: ppx1=%.3f ppx3=%.3f ppx10=%.3f" % (ppx1, ppx3, ppx10))

assert all(0 < ppx < 500 for ppx in (ppx1, ppx3, ppx10)), "perplexity should be non-negative and reasonably small"
assert ppx1 > ppx3 > ppx10, "higher N models should overfit and "
assert np.isfinite(ppx_missing) and ppx_missing > 10 ** 6, "missing words should have large but finite perplexity. " \
    " Make sure you use min_logprob right"
assert np.allclose([ppx1, ppx3, ppx10], (318.2132342216302, 1.5199996213739575, 1.1838145037901249))
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 67519.38it/s]
# 100%|██████████| 100/100 [00:00<00:00, 29275.52it/s]
# 100%|██████████| 100/100 [00:00<00:00, 31645.57it/s]
# Perplexities: ppx1=318.213 ppx3=1.520 ppx10=1.184
# /var/folders/zm/dkxvs8l50z3g4ygcywqr67qr0000gn/T/ipykernel_8857/1299495968.py:16: RuntimeWarning: divide by zero encountered in log
#   prob = max(np.log(prob), min_logprob)

# %% [markdown]
# Now let's measure the actual perplexity: we'll split the data into train and test and score model on test data only.

# %%
from sklearn.model_selection import train_test_split
train_lines, test_lines = train_test_split(lines, test_size=0.25, random_state=42)

for n in (1, 2, 3):
    lm = NGramLanguageModel(n=n, lines=train_lines)
    ppx = perplexity(lm, test_lines)
    print("N = %i, Perplexity = %.5f" % (n, ppx))
# Out:
# 100%|██████████| 30750/30750 [00:01<00:00, 21681.80it/s]
# /var/folders/zm/dkxvs8l50z3g4ygcywqr67qr0000gn/T/ipykernel_8857/1299495968.py:16: RuntimeWarning: divide by zero encountered in log
#   prob = max(np.log(prob), min_logprob)
# N = 1, Perplexity = 1832.23136
# 100%|██████████| 30750/30750 [00:02<00:00, 12600.98it/s]
# N = 2, Perplexity = 85653987.28543
# 100%|██████████| 30750/30750 [00:04<00:00, 6410.29it/s]
# N = 3, Perplexity = 61999196239895057137664.00000

# %%
# whoops, it just blew up :)

# %% [markdown]
# ### LM Smoothing
#
# The problem with our simple language model is that whenever it encounters an n-gram it has never seen before, it assigns it with the probabilitiy of 0. Every time this happens, perplexity explodes.
#
# To battle this issue, there's a technique called __smoothing__. The core idea is to modify counts in a way that prevents probabilities from getting too low. The simplest algorithm here is Additive smoothing (aka [Lapace smoothing](https://en.wikipedia.org/wiki/Additive_smoothing)):
#
# $$ P(w_t | prefix) = { Count(prefix, w_t) + \delta \over \sum_{\hat w} (Count(prefix, \hat w) + \delta) } $$
#
# If counts for a given prefix are low, additive smoothing will adjust probabilities to a more uniform distribution. Not that the summation in the denominator goes over _all words in the vocabulary_.
#
# Here's an example code we've implemented for you:

# %%
count_ngrams(lines, 3)
# Out:
# 100%|██████████| 41000/41000 [00:07<00:00, 5774.75it/s]
# defaultdict(collections.Counter,
#             {('_UNK_',
#               '_UNK_'): Counter({'a': 3207,
#                       'learning': 1289,
#                       'the': 913,
#                       'an': 818,
#                       'deep': 785,
#                       'on': 778,
#                       'multi': 376,
#                       'towards': 365,
#                       'efficient': 323,
#                       'fast': 323,
#                       'automatic': 259,
#                       'robust': 248,
#                       'unsupervised': 228,
#                       'neural': 226,
#                       'using': 217,
#                       'improving': 211,
#                       'online': 200,
#                       'bayesian': 197,
#                       'image': 195,
#                       'sparse': 144,
#                       'stochastic': 144,
#                       'adaptive': 139,
#                       'joint': 138,
#                       'optimal': 128,
#                       'semi': 126,
#                       'probabilistic': 126,
#                       'modeling': 126,
#                       'feature': 122,
#                       'distributed': 118,
#                       'how': 116,
#                       'predicting': 116,
#                       'from': 113,
#                       'detecting': 110,
#                       'dynamic': 110,
#                       'semantic': 108,
#                       'real': 108,
#                       'large': 107,
#                       'visual': 104,
#                       'hierarchical': 103,
#                       'improved': 103,
#                       'non': 101,
#                       'scalable': 99,
#                       '3d': 97,
#                       'active': 95,
#                       'variational': 94,
#                       'understanding': 93,
#                       'end': 92,
#                       'data': 92,
#                       'high': 91,
#                       'exploiting': 91,
#                       'convolutional': 90,
#                       'automated': 89,
#                       'self': 89,
#                       'exploring': 88,
#                       'clustering': 87,
#                       'what': 87,
#                       'local': 86,
#                       'cross': 84,
#                       'adversarial': 83,
#                       'graph': 83,
#                       'training': 82,
#                       'statistical': 82,
#                       'recurrent': 81,
#                       'toward': 81,
#                       'machine': 81,
#                       'combining': 79,
#                       'generating': 78,
#                       'generalized': 78,
#                       'classification': 75,
#                       'analysis': 75,
#                       'object': 70,
#                       'structured': 70,
#                       'face': 70,
#                       'solving': 70,
#                       'identifying': 69,
#                       'supervised': 68,
#                       'building': 67,
#                       'multiple': 67,
#                       'model': 65,
#                       'temporal': 65,
#                       'knowledge': 64,
#                       'estimating': 64,
#                       'information': 64,
#                       'hybrid': 62,
#                       'human': 62,
#                       'proceedings': 62,
#                       'beyond': 61,
#                       'generative': 61,
#                       'video': 60,
#                       'low': 60,
#                       'kernel': 58,
#                       'one': 58,
#                       'linear': 57,
#                       'evaluating': 57,
#                       'application': 57,
#                       'spectral': 56,
#                       'new': 56,
#                       'two': 56,
#                       'reasoning': 55,
#                       'can': 55,
#                       'single': 55,
#                       'approximate': 55,
#                       'random': 54,
#                       'mining': 54,
#                       'optimizing': 53,
#                       'computational': 53,
#                       'context': 51,
#                       'artificial': 51,
#                       'gaussian': 50,
#                       'evolutionary': 50,
#                       'incremental': 50,
#                       'reinforcement': 50,
#                       'domain': 49,
#                       'finding': 49,
#                       'detection': 49,
#                       'causal': 48,
#                       'comparing': 47,
#                       'measuring': 47,
#                       'when': 47,
#                       'discriminative': 47,
#                       'evaluation': 47,
#                       'design': 47,
#                       'sequential': 46,
#                       'parallel': 46,
#                       'weakly': 46,
#                       'quantum': 46,
#                       'multimodal': 45,
#                       'comparison': 45,
#                       'latent': 44,
#                       'discovering': 44,
#                       'revisiting': 44,
#                       'conditional': 43,
#                       'interactive': 43,
#                       'gradient': 43,
#                       'fuzzy': 43,
#                       'global': 43,
#                       'performance': 43,
#                       'decision': 42,
#                       'time': 42,
#                       'transfer': 41,
#                       'zero': 41,
#                       'language': 41,
#                       'modelling': 41,
#                       'optimization': 41,
#                       'inferring': 41,
#                       'iterative': 41,
#                       'text': 40,
#                       'genetic': 40,
#                       'memory': 40,
#                       'computing': 40,
#                       'effective': 39,
#                       'convergence': 39,
#                       'maximum': 39,
#                       'tracking': 39,
#                       '"': 39,
#                       'leveraging': 39,
#                       'universal': 38,
#                       'nonparametric': 38,
#                       'is': 38,
#                       'simultaneous': 38,
#                       'convex': 38,
#                       'dual': 37,
#                       'fine': 37,
#                       'exact': 37,
#                       'simple': 37,
#                       'prediction': 37,
#                       'group': 37,
#                       'spatial': 36,
#                       'geometric': 36,
#                       'extracting': 36,
#                       'why': 35,
#                       'attention': 35,
#                       'enhancing': 35,
#                       'applying': 35,
#                       'evolving': 35,
#                       'enhanced': 35,
#                       'predictive': 35,
#                       'query': 35,
#                       'integrating': 34,
#                       'network': 34,
#                       'near': 34,
#                       'collaborative': 33,
#                       'sentiment': 33,
#                       'segmentation': 33,
#                       'practical': 33,
#                       'fully': 33,
#                       'word': 33,
#                       'some': 33,
#                       'analyzing': 32,
#                       'interpretable': 32,
#                       'ensemble': 32,
#                       'natural': 31,
#                       'scaling': 31,
#                       'boosting': 31,
#                       'action': 31,
#                       'belief': 31,
#                       'intelligent': 31,
#                       'tensor': 30,
#                       'inference': 30,
#                       'continuous': 30,
#                       'structure': 30,
#                       'constrained': 29,
#                       'accelerated': 29,
#                       'long': 28,
#                       'depth': 28,
#                       'blind': 28,
#                       'facial': 28,
#                       'comparative': 28,
#                       'incorporating': 27,
#                       'sequence': 27,
#                       'evolution': 27,
#                       'super': 27,
#                       'visualizing': 27,
#                       'co': 27,
#                       'representation': 27,
#                       'complex': 27,
#                       'characterizing': 27,
#                       'identification': 27,
#                       'shape': 27,
#                       'complexity': 27,
#                       'content': 27,
#                       'development': 27,
#                       'first': 26,
#                       'classifying': 26,
#                       'pac': 26,
#                       'contextual': 26,
#                       'compressive': 26,
#                       'cost': 26,
#                       'generalization': 25,
#                       'dense': 25,
#                       'accelerating': 25,
#                       'recognizing': 25,
#                       'quantifying': 25,
#                       'investigating': 25,
#                       'algorithms': 25,
#                       'empirical': 25,
#                       'weighted': 25,
#                       'faster': 25,
#                       'are': 25,
#                       'safe': 25,
#                       'matrix': 25,
#                       'estimation': 25,
#                       'accurate': 25,
#                       'extending': 25,
#                       'discrete': 24,
#                       'direct': 24,
#                       'introduction': 24,
#                       'nonlinear': 24,
#                       'differentially': 24,
#                       'novel': 24,
#                       'parameter': 23,
#                       'mapping': 23,
#                       'block': 23,
#                       'soft': 23,
#                       'structural': 23,
#                       'topic': 23,
#                       'theoretical': 23,
#                       'randomized': 23,
#                       'personalized': 23,
#                       'phase': 23,
#                       'general': 23,
#                       'representing': 23,
#                       'sample': 22,
#                       'making': 22,
#                       'in': 22,
#                       'entropy': 22,
#                       'autonomous': 22,
#                       'no': 22,
#                       'scale': 22,
#                       'color': 22,
#                       'max': 22,
#                       'speech': 22,
#                       'inverse': 22,
#                       'recognition': 22,
#                       'texture': 22,
#                       'spatio': 21,
#                       'cnn': 21,
#                       'logic': 21,
#                       'do': 21,
#                       'brain': 21,
#                       'vision': 21,
#                       'embedding': 21,
#                       'similarity': 21,
#                       'open': 21,
#                       'combinatorial': 21,
#                       'constraint': 21,
#                       'binary': 21,
#                       'event': 20,
#                       'pose': 20,
#                       'dimensionality': 20,
#                       'meta': 20,
#                       'motion': 20,
#                       'anomaly': 20,
#                       'generalizing': 20,
#                       'tree': 20,
#                       'matching': 20,
#                       'top': 20,
#                       'greedy': 20,
#                       'dictionary': 20,
#                       'ranking': 20,
#                       'scene': 20,
#                       'risk': 20,
#                       'assessing': 20,
#                       'computer': 20,
#                       'residual': 19,
#                       'constructing': 19,
#                       'survey': 19,
#                       'encoding': 19,
#                       'geometry': 19,
#                       'flexible': 19,
#                       'early': 19,
#                       'asymptotic': 19,
#                       'testing': 19,
#                       'manifold': 19,
#                       'pattern': 19,
#                       'consistent': 19,
#                       'subspace': 19,
#                       'compact': 19,
#                       'hyperspectral': 19,
#                       'robustness': 19,
#                       'recovering': 19,
#                       'ontology': 19,
#                       'planning': 19,
#                       'digital': 19,
#                       'social': 19,
#                       'explaining': 18,
#                       'multilingual': 18,
#                       'wavelet': 18,
#                       'question': 18,
#                       'cognitive': 18,
#                       'advances': 18,
#                       'regularized': 18,
#                       'particle': 18,
#                       'energy': 18,
#                       'partial': 18,
#                       'compositional': 18,
#                       'stability': 18,
#                       'graphical': 18,
#                       'regret': 18,
#                       'algorithmic': 18,
#                       'minimax': 18,
#                       'reconstruction': 18,
#                       'diffusion': 18,
#                       'saliency': 18,
#                       'selective': 18,
#                       'rule': 18,
#                       'logical': 18,
#                       'task': 17,
#                       'sentence': 17,
#                       'handwritten': 17,
#                       'theory': 17,
#                       'denoising': 17,
#                       'benchmarking': 17,
#                       'variable': 17,
#                       'where': 17,
#                       'approximation': 17,
#                       'bidirectional': 17,
#                       'recursive': 17,
#                       'does': 17,
#                       'developing': 17,
#                       'to': 17,
#                       'noisy': 17,
#                       'mixed': 17,
#                       'communication': 17,
#                       'label': 17,
#                       'markov': 17,
#                       'policy': 17,
#                       'tight': 17,
#                       'medical': 17,
#                       'interpreting': 17,
#                       '$': 17,
#                       'web': 17,
#                       'person': 17,
#                       'reducing': 17,
#                       'monte': 17,
#                       'light': 17,
#                       'density': 16,
#                       'path': 16,
#                       'mean': 16,
#                       'implicit': 16,
#                       'full': 16,
#                       'distribution': 16,
#                       'provable': 16,
#                       'concept': 16,
#                       'rapid': 16,
#                       'implementation': 16,
#                       'use': 16,
#                       'distance': 16,
#                       'k': 16,
#                       'state': 16,
#                       'parsing': 16,
#                       'sparsity': 16,
#                       'multiscale': 16,
#                       'finite': 16,
#                       'qualitative': 16,
#                       'extraction': 16,
#                       'regularization': 15,
#                       'bridging': 15,
#                       'character': 15,
#                       'uncertainty': 15,
#                       'stacked': 15,
#                       'virtual': 15,
#                       'functional': 15,
#                       'three': 15,
#                       'recent': 15,
#                       'bounded': 15,
#                       'metric': 15,
#                       'streaming': 15,
#                       'variance': 15,
#                       'asynchronous': 15,
#                       'auto': 15,
#                       'symmetry': 15,
#                       'user': 15,
#                       'creating': 15,
#                       'fusion': 15,
#                       'implementing': 15,
#                       'rank': 15,
#                       'decentralized': 15,
#                       'forecasting': 15,
#                       'edge': 15,
#                       'designing': 15,
#                       'camera': 15,
#                       'synthesizing': 14,
#                       'value': 14,
#                       'lexical': 14,
#                       'lifted': 14,
#                       'minimal': 14,
#                       'parametric': 14,
#                       'review': 14,
#                       'counterfactual': 14,
#                       'multivariate': 14,
#                       'transductive': 14,
#                       'thompson': 14,
#                       'error': 14,
#                       'exploration': 14,
#                       'multiclass': 14,
#                       'higher': 14,
#                       'determining': 14,
#                       'riemannian': 14,
#                       'class': 14,
#                       'guided': 14,
#                       'expectation': 14,
#                       'balancing': 14,
#                       'quality': 14,
#                       'capturing': 14,
#                       'outlier': 14,
#                       'differential': 14,
#                       'approximating': 14,
#                       'speeding': 14,
#                       'efficiently': 14,
#                       'consistency': 14,
#                       'integration': 14,
#                       'document': 13,
#                       'overcoming': 13,
#                       'pixel': 13,
#                       'compression': 13,
#                       'positive': 13,
#                       'generic': 13,
#                       'spatially': 13,
#                       'unifying': 13,
#                       'better': 13,
#                       'morphological': 13,
#                       'bootstrapping': 13,
#                       'inductive': 13,
#                       'technical': 13,
#                       'anytime': 13,
#                       'quantitative': 13,
#                       'stable': 13,
#                       'hand': 13,
#                       'recovery': 13,
#                       'evidence': 13,
#                       'translating': 13,
#                       'automatically': 13,
#                       'agent': 13,
#                       'minimum': 13,
#                       'challenges': 13,
#                       'diversity': 13,
#                       'who': 13,
#                       'numerical': 13,
#                       'part': 13,
#                       'multiresolution': 12,
#                       'deeply': 12,
#                       'emergence': 12,
#                       'unified': 12,
#                       'dependency': 12,
#                       'batch': 12,
#                       'principal': 12,
#                       'locally': 12,
#                       'learned': 12,
#                       'crowdsourcing': 12,
#                       'seeing': 12,
#                       'investigation': 12,
#                       'managing': 12,
#                       'asymmetric': 12,
#                       'linguistic': 12,
#                       'decomposition': 12,
#                       'sub': 12,
#                       'symbolic': 12,
#                       'skin': 12,
#                       'offline': 12,
#                       'target': 12,
#                       'relative': 12,
#                       'noise': 12,
#                       'second': 12,
#                       'compressed': 12,
#                       'breaking': 12,
#                       'orthogonal': 12,
#                       'infinite': 12,
#                       'least': 12,
#                       'highly': 12,
#                       'more': 12,
#                       'proximal': 12,
#                       'extended': 12,
#                       'optical': 12,
#                       'syntactic': 12,
#                       'black': 12,
#                       'enabling': 12,
#                       'privacy': 12,
#                       'heuristic': 12,
#                       'traffic': 12,
#                       'piecewise': 11,
#                       'sensitivity': 11,
#                       'alternating': 11,
#                       'adapting': 11,
#                       'progressive': 11,
#                       'mathematical': 11,
#                       'formal': 11,
#                       'rethinking': 11,
#                       'globally': 11,
#                       'crowd': 11,
#                       'correlation': 11,
#                       'smart': 11,
#                       'hidden': 11,
#                       'sampling': 11,
#                       'all': 11,
#                       'dropout': 11,
#                       'searching': 11,
#                       'attentive': 11,
#                       'best': 11,
#                       'inducing': 11,
#                       'order': 11,
#                       'authorship': 11,
#                       'linking': 11,
#                       'increasing': 11,
#                       'grounding': 11,
#                       'extreme': 11,
#                       'vector': 11,
#                       'closed': 11,
#                       'notes': 11,
#                       'properties': 11,
#                       'modular': 11,
#                       'short': 11,
#                       'pseudo': 11,
#                       'intrinsic': 11,
#                       'deformable': 11,
#                       'exponential': 11,
#                       'emotion': 11,
#                       'polynomial': 11,
#                       'view': 11,
#                       'n': 11,
#                       'algebraic': 11,
#                       'confidence': 11,
#                       'applications': 11,
#                       'restricted': 11,
#                       'selecting': 11,
#                       'speaker': 11,
#                       'extension': 11,
#                       'fusing': 11,
#                       'analysing': 11,
#                       'guaranteed': 11,
#                       'handling': 11,
#                       'hardware': 11,
#                       'instance': 11,
#                       'probability': 11,
#                       'fingerprint': 11,
#                       'monocular': 11,
#                       'avoiding': 10,
#                       'teaching': 10,
#                       'gated': 10,
#                       'resource': 10,
#                       'jointly': 10,
#                       'syntax': 10,
#                       'lstm': 10,
#                       'diverse': 10,
#                       'named': 10,
#                       'small': 10,
#                       'very': 10,
#                       'discovery': 10,
#                       'relational': 10,
#                       'pruning': 10,
#                       'disentangling': 10,
#                       'tractable': 10,
#                       'expert': 10,
#                       'heterogeneous': 10,
#                       'visualization': 10,
#                       'not': 10,
#                       'distributional': 10,
#                       'support': 10,
#                       'generation': 10,
#                       'audio': 10,
#                       'influence': 10,
#                       '(': 10,
#                       'double': 10,
#                       'off': 10,
#                       'experimental': 10,
#                       'loss': 10,
#                       'nested': 10,
#                       'total': 10,
#                       'post': 10,
#                       'introducing': 10,
#                       'gender': 10,
#                       'evidential': 10,
#                       'salient': 10,
#                       'cooperative': 10,
#                       'parameterized': 10,
#                       'associative': 10,
#                       'dimension': 10,
#                       'poisson': 10,
#                       'uniform': 10,
#                       'achieving': 10,
#                       'big': 10,
#                       'fair': 10,
#                       'synthesis': 10,
#                       'fixed': 10,
#                       'cascaded': 10,
#                       'opinion': 10,
#                       'arabic': 10,
#                       'collective': 10,
#                       'characterization': 10,
#                       'fault': 10,
#                       'transferring': 9,
#                       'flow': 9,
#                       'integrated': 9,
#                       'competitive': 9,
#                       'invariant': 9,
#                       'product': 9,
#                       'addressing': 9,
#                       'lattice': 9,
#                       'demystifying': 9,
#                       'simulating': 9,
#                       'occlusion': 9,
#                       'reservoir': 9,
#                       'gpu': 9,
#                       'wide': 9,
#                       'experiments': 9,
#                       'source': 9,
#                       'decoding': 9,
#                       'search': 9,
#                       'bandit': 9,
#                       'deterministic': 9,
#                       'show': 9,
#                       'embedded': 9,
#                       'playing': 9,
#                       'free': 9,
#                       'cluster': 9,
#                       'taming': 9,
#                       'coupled': 9,
#                       'boundary': 9,
#                       'doubly': 9,
#                       'divide': 9,
#                       'augmented': 9,
#                       'optimistic': 9,
#                       'reduced': 9,
#                       'updating': 9,
#                       'study': 9,
#                       'surrogate': 9,
#                       'reconstructing': 9,
#                       'wasserstein': 9,
#                       'multitask': 9,
#                       'simulated': 9,
#                       'methods': 9,
#                       'cascade': 9,
#                       'contrastive': 9,
#                       '2d': 9,
#                       'augmenting': 9,
#                       'efficiency': 9,
#                       'fractal': 9,
#                       'community': 9,
#                       'calibration': 9,
#                       'effects': 9,
#                       'directional': 9,
#                       'entity': 9,
#                       'simulation': 9,
#                       'combined': 9,
#                       'about': 9,
#                       'chinese': 9,
#                       'rational': 9,
#                       'region': 9,
#                       'r': 9,
#                       'vehicle': 9,
#                       'egocentric': 9,
#                       'improvements': 8,
#                       'validation': 8,
#                       'rotation': 8,
#                       'relation': 8,
#                       'deriving': 8,
#                       'autoencoder': 8,
#                       'systematic': 8,
#                       'massively': 8,
#                       'curriculum': 8,
#                       'missing': 8,
#                       'semantics': 8,
#                       'lower': 8,
#                       'it': 8,
#                       'look': 8,
#                       'phrase': 8,
#                       'oracle': 8,
#                       'bi': 8,
#                       'e': 8,
#                       'impact': 8,
#                       'computationally': 8,
#                       'role': 8,
#                       'reading': 8,
#                       'consensus': 8,
#                       'objective': 8,
#                       'map': 8,
#                       'unbiased': 8,
#                       'ensembles': 8,
#                       'importance': 8,
#                       'hashing': 8,
#                       'f': 8,
#                       'projection': 8,
#                       'studying': 8,
#                       'emotional': 8,
#                       'multilinear': 8,
#                       'convergent': 8,
#                       'twitter': 8,
#                       'separating': 8,
#                       'plan': 8,
#                       'complete': 8,
#                       'back': 8,
#                       'space': 8,
#                       'bio': 8,
#                       'template': 8,
#                       'indoor': 8,
#                       'less': 8,
#                       'bag': 8,
#                       'possibilistic': 8,
#                       'good': 8,
#                       'normalized': 8,
#                       'induction': 8,
#                       'ai': 8,
#                       'bandits': 8,
#                       'regression': 8,
#                       'dealing': 8,
#                       'cloud': 8,
#                       'multiplicative': 8,
#                       'nonconvex': 8,
#                       'adaptation': 8,
#                       'relaxed': 8,
#                       'road': 8,
#                       'utilizing': 8,
#                       'generalised': 8,
#                       'mobile': 8,
#                       'anisotropic': 8,
#                       'hyper': 8,
#                       'perceptual': 8,
#                       'sar': 8,
#                       'unconstrained': 8,
#                       'corpus': 8,
#                       'aspect': 8,
#                       'gibbs': 8,
#                       'spatiotemporal': 8,
#                       'note': 8,
#                       'translation': 8,
#                       'affine': 8,
#                       'basic': 8,
#                       'strong': 8,
#                       'improvement': 8,
#                       'resolution': 8,
#                       'annotating': 8,
#                       'foundations': 8,
#                       'construction': 8,
#                       'p': 8,
#                       'synthetic': 8,
#                       'causes': 8,
#                       'propositional': 8,
#                       'attribute': 8,
#                       'enhancement': 8,
#                       'background': 8,
#                       'activity': 8,
#                       'sketch': 8,
#                       'skeleton': 8,
#                       'semantically': 7,
#                       'ask': 7,
#                       'log': 7,
#                       'grounded': 7,
#                       'acquiring': 7,
#                       'imitation': 7,
#                       'out': 7,
#                       'submodular': 7,
#                       'dataset': 7,
#                       'cortical': 7,
#                       'fitness': 7,
#                       'common': 7,
#                       'biologically': 7,
#                       'identity': 7,
#                       'compressing': 7,
#                       'fisher': 7,
#                       'contour': 7,
#                       'composite': 7,
#                       'multidimensional': 7,
#                       'resolving': 7,
#                       'robot': 7,
#                       'frame': 7,
#                       'software': 7,
#                       'uncovering': 7,
#                       'factored': 7,
#                       'distinguishing': 7,
#                       'bayes': 7,
#                       'transforming': 7,
#                       'mixture': 7,
#                       'algorithm': 7,
#                       'train': 7,
#                       'provably': 7,
#                       'fairness': 7,
#                       'budget': 7,
#                       'control': 7,
#                       '$\\': 7,
#                       'combination': 7,
#                       'kernelized': 7,
#                       'smoothed': 7,
#                       'few': 7,
#                       'topology': 7,
#                       'gene': 7,
#                       'volumetric': 7,
#                       'dependent': 7,
#                       'multispectral': 7,
#                       'nearly': 7,
#                       "'": 7,
#                       'strategic': 7,
#                       'pre': 7,
#                       'utility': 7,
#                       'dirichlet': 7,
#                       'prior': 7,
#                       'correlated': 7,
#                       'preference': 7,
#                       'which': 7,
#                       'marginal': 7,
#                       'kernels': 7,
#                       'forward': 7,
#                       'critical': 7,
#                       'causality': 7,
#                       'link': 7,
#                       'interval': 7,
#                       'constant': 7,
#                       'sensor': 7,
#                       'median': 7,
#                       'cell': 7,
#                       'automating': 7,
#                       'd': 7,
#                       'point': 7,
#                       'stratified': 7,
#                       'revealing': 7,
#                       'optimized': 7,
#                       'controlling': 7,
#                       'un': 7,
#                       'node': 7,
#                       'discussion': 7,
#                       'problem': 7,
#                       'proposal': 7,
#                       'concurrent': 7,
#                       'dialogue': 7,
#                       'les': 7,
#                       'siamese': 7,
#                       'assessment': 7,
#                       'additive': 7,
#                       'you': 7,
#                       'material': 7,
#                       'coarse': 6,
#                       'describing': 6,
#                       'de': 6,
#                       'quasi': 6,
#                       'input': 6,
#                       'regularizing': 6,
#                       'monitoring': 6,
#                       'symbol': 6,
#                       'filtering': 6,
#                       'message': 6,
#                       'harnessing': 6,
#                       'abstract': 6,
#                       'guiding': 6,
#                       'c': 6,
#                       'bounding': 6,
#                       'examining': 6,
#                       'feedforward': 6,
#                       'differentiable': 6,
#                       'going': 6,
#                       'auxiliary': 6,
#                       'explainable': 6,
#                       'controlled': 6,
#                       'attend': 6,
#                       'parallelizing': 6,
#                       'weight': 6,
#                       'getting': 6,
#                       'continual': 6,
#                       'population': 6,
#                       'techniques': 6,
#                       'sum': 6,
#                       'refining': 6,
#                       'grammar': 6,
#                       'detect': 6,
#                       'compiling': 6,
#                       'counting': 6,
#                       'q': 6,
#                       'rough': 6,
#                       'overlapping': 6,
#                       'advancing': 6,
#                       'reliable': 6,
#                       'shallow': 6,
#                       'verifying': 6,
#                       'linearized': 6,
#                       'spontaneous': 6,
#                       'perception': 6,
#                       'boltzmann': 6,
#                       'truncated': 6,
#                       'pairwise': 6,
#                       'simultaneously': 6,
#                       'emergent': 6,
#                       'system': 6,
#                       'trainable': 6,
#                       'pca': 6,
#                       'annotation': 6,
#                       'gray': 6,
#                       'left': 6,
#                       'game': 6,
#                       'abductive': 6,
#                       'appearance': 6,
#                       'relevant': 6,
#                       'l1': 6,
#                       'defensive': 6,
#                       'performing': 6,
#                       'sketching': 6,
#                       'negative': 6,
#                       'sign': 6,
#                       'posterior': 6,
#                       'fourier': 6,
#                       'minimizing': 6,
#                       'classifier': 6,
#                       'bias': 6,
#                       're': 6,
#                       'fractional': 6,
#                       'bounds': 6,
#                       'models': 6,
#                       'should': 6,
#                       'every': 6,
#                       'stabilizing': 6,
#                       'location': 6,
#                       'symmetric': 6,
#                       's': 6,
#                       'topological': 6,
#                       'pedestrian': 6,
#                       'densely': 6,
#                       'land': 6,
#                       'calculating': 6,
#                       'viewpoint': 6,
#                       'robotic': 6,
#                       'behavior': 6,
#                       'multilevel': 6,
#                       'actor': 6,
#                       'sharp': 6,
#                       'private': 6,
#                       'significance': 6,
#                       'frequency': 6,
#                       'nonnegative': 6,
#                       'redundancy': 6,
#                       'process': 6,
#                       'selection': 6,
#                       'average': 6,
#                       'aggregating': 6,
#                       'solution': 6,
#                       'style': 6,
#                       'refinement': 6,
#                       'une': 6,
#                       'grammatical': 6,
#                       'argument': 6,
#                       'dynamics': 6,
#                       'acoustic': 6,
#                       'see': 6,
#                       'merging': 6,
#                       'verification': 6,
#                       'persistent': 6,
#                       'integral': 6,
#                       'conceptualization': 6,
#                       'superpixel': 6,
#                       'patch': 6,
#                       'ct': 6,
#                       'listen': 5,
#                       'parsimonious': 5,
#                       'hyperparameter': 5,
#                       'deciding': 5,
#                       'don': 5,
#                       'feedback': 5,
#                       'transition': 5,
#                       'clinical': 5,
#                       'stance': 5,
#                       'grid': 5,
#                       'relevance': 5,
#                       'adversarially': 5,
#                       'iris': 5,
#                       ...}),
#              ('_UNK_',
#               'dual'): Counter({'-': 9,
#                       'memory': 2,
#                       'attention': 2,
#                       'path': 2,
#                       'recurrent': 1,
#                       'rectified': 1,
#                       'teaching': 1,
#                       'iterative': 1,
#                       'supervised': 1,
#                       'discriminator': 1,
#                       'control': 1,
#                       'coordinate': 1,
#                       'principal': 1,
#                       'smoothing': 1,
#                       'learning': 1,
#                       'language': 1,
#                       'long': 1,
#                       'modelling': 1,
#                       'decomposition': 1,
#                       'extrapolation': 1,
#                       'deep': 1,
#                       'recovery': 1,
#                       'motion': 1,
#                       'asymmetric': 1,
#                       'augmented': 1,
#                       'density': 1}),
#              ('dual', 'recurrent'): Counter({'attention': 1}),
#              ('recurrent',
#               'attention'): Counter({'mechanism': 5,
#                       'model': 4,
#                       'network': 4,
#                       'models': 3,
#                       'units': 2,
#                       'networks': 2,
#                       'modeling': 1,
#                       'densenet': 1,
#                       ';': 1,
#                       'and': 1,
#                       'reinforcement': 1,
#                       'module': 1}),
#              ('attention', 'units'): Counter({'for': 1, 'offers': 1}),
#              ('units',
#               'for'): Counter({'visual': 1,
#                       'information': 1,
#                       'natural': 1,
#                       'smt': 1,
#                       'statistical': 1,
#                       'this': 1,
#                       'non': 1,
#                       'ctc': 1,
#                       'goal': 1,
#                       'speech': 1,
#                       'training': 1,
#                       'improving': 1,
#                       'semantic': 1,
#                       'combining': 1,
#                       'automated': 1,
#                       'normalization': 1,
#                       'deep': 1,
#                       'efficient': 1,
#                       'which': 1,
#                       'streaming': 1,
#                       'improved': 1}),
#              ('for',
#               'visual'): Counter({'tracking': 47,
#                       'recognition': 37,
#                       'question': 35,
#                       'object': 29,
#                       'reasoning': 12,
#                       'data': 8,
#                       'place': 7,
#                       'speech': 6,
#                       'dialog': 5,
#                       'saliency': 5,
#                       'odometry': 5,
#                       'navigation': 4,
#                       '-': 4,
#                       'learning': 4,
#                       'domain': 4,
#                       'and': 3,
#                       'attention': 3,
#                       'interpretation': 3,
#                       'control': 3,
#                       'search': 3,
#                       'perception': 3,
#                       'exploration': 3,
#                       'understanding': 3,
#                       'information': 3,
#                       'sentiment': 3,
#                       'captioning': 2,
#                       'ai': 2,
#                       'pattern': 2,
#                       'inputs': 2,
#                       'localization': 2,
#                       'inspection': 2,
#                       'images': 2,
#                       'mining': 2,
#                       'surveillance': 2,
#                       'face': 2,
#                       'content': 2,
#                       'bow': 2,
#                       'representation': 2,
#                       'correspondence': 2,
#                       'applications': 2,
#                       'relation': 2,
#                       'classification': 2,
#                       'aesthetic': 2,
#                       'servoing': 2,
#                       'loop': 2,
#                       'analysis': 1,
#                       'grouping': 1,
#                       'representations': 1,
#                       'decision': 1,
#                       'concept': 1,
#                       'modality': 1,
#                       'arts': 1,
#                       'reinforcement': 1,
#                       'relationship': 1,
#                       'paragraph': 1,
#                       'semantic': 1,
#                       'events': 1,
#                       'explanations': 1,
#                       'emotion': 1,
#                       'intuitive': 1,
#                       'category': 1,
#                       'signals': 1,
#                       'blending': 1,
#                       'descriptor': 1,
#                       'categorization': 1,
#                       'matching': 1,
#                       'scene': 1,
#                       'ego': 1,
#                       'distortion': 1,
#                       'effects': 1,
#                       'features': 1,
#                       'vocabulary': 1,
#                       'grounding': 1,
#                       'scenes': 1,
#                       'identification': 1,
#                       'impact': 1,
#                       'classes': 1,
#                       'comparisons': 1,
#                       'inference': 1,
#                       'scrutiny': 1,
#                       'bag': 1,
#                       'color': 1,
#                       'dictionaries': 1,
#                       'contents': 1,
#                       'similarity': 1,
#                       'descriptions': 1,
#                       'madlibs': 1,
#                       'instance': 1,
#                       'receptive': 1,
#                       'attribute': 1,
#                       'feature': 1,
#                       'sensor': 1,
#                       'discovery': 1,
#                       'processes': 1,
#                       'discriminative': 1,
#                       'forecasting': 1,
#                       'census': 1,
#                       'slam': 1,
#                       'patterns': 1,
#                       'attribution': 1,
#                       'task': 1,
#                       'action': 1,
#                       'dialogue': 1,
#                       'objects': 1,
#                       'questions': 1,
#                       'tasks': 1,
#                       'animal': 1,
#                       'based': 1,
#                       'optimization': 1,
#                       'qa': 1,
#                       'free': 1,
#                       'stimuli': 1}),
#              ('visual',
#               'question'): Counter({'answering': 166,
#                       '-': 7,
#                       'generation': 7,
#                       'and': 2,
#                       '.': 2,
#                       ':': 1,
#                       'whether': 1,
#                       'is': 1,
#                       'answer': 1}),
#              ('question',
#               'answering'): Counter({'(': 123,
#                       ';': 84,
#                       '.': 50,
#                       ',': 29,
#                       'system': 25,
#                       'and': 23,
#                       'task': 21,
#                       'dataset': 21,
#                       'systems': 18,
#                       'tasks': 14,
#                       'in': 12,
#                       ':': 12,
#                       'is': 11,
#                       'models': 10,
#                       'with': 8,
#                       'by': 7,
#                       'datasets': 6,
#                       'about': 5,
#                       'model': 5,
#                       'over': 5,
#                       'using': 5,
#                       'on': 5,
#                       'via': 4,
#                       'that': 3,
#                       'forums': 3,
#                       'as': 3,
#                       'from': 3,
#                       'are': 3,
#                       'for': 3,
#                       'at': 2,
#                       'when': 2,
#                       'can': 2,
#                       'etc': 2,
#                       'challenge': 2,
#                       'module': 2,
#                       'engine': 2,
#                       'has': 2,
#                       'methods': 2,
#                       'approach': 2,
#                       'platforms': 2,
#                       'or': 2,
#                       'into': 1,
#                       'of': 1,
#                       'raises': 1,
#                       'where': 1,
#                       'under': 1,
#                       'require': 1,
#                       'challenges': 1,
#                       'algorithms': 1,
#                       'approaches': 1,
#                       'due': 1,
#                       'benchmarks': 1,
#                       ')': 1,
#                       'algorithm': 1,
#                       '?': 1,
#                       'subtasks': 1,
#                       'site': 1,
#                       'demonstrates': 1,
#                       'assumes': 1,
#                       '".': 1,
#                       'through': 1,
#                       'against': 1,
#                       'baseline': 1,
#                       'involves': 1,
#                       'field': 1,
#                       '-': 1,
#                       'metrics': 1,
#                       'communities': 1,
#                       'community': 1,
#                       'learning': 1,
#                       'dialogue': 1,
#                       'process': 1,
#                       'used': 1,
#                       'dynamically': 1,
#                       'based': 1,
#                       'which': 1,
#                       'architectures': 1,
#                       'show': 1,
#                       'network': 1,
#                       'method': 1,
#                       'shows': 1,
#                       'requires': 1,
#                       'services': 1,
#                       'along': 1,
#                       'today': 1,
#                       'pipeline': 1,
#                       'metasystem': 1,
#                       'framework': 1}),
#              ('answering',
#               ';'): Counter({'we': 18,
#                       'this': 13,
#                       'visual': 9,
#                       'in': 7,
#                       'question': 5,
#                       'the': 4,
#                       'a': 3,
#                       'recently': 3,
#                       'while': 2,
# ...
#                       'accurately': 1,
#                       'games': 1,
#                       'objectives': 1,
#                       'correspondences': 1,
#                       'intermolecular': 1,
#                       'embrace': 1,
#                       'classical': 1,
#                       'drawbacks': 1,
#                       'takes': 1,
#                       'very': 1,
#                       'understanding': 1,
#                       'boomed': 1,
#                       'dense': 1,
#                       'scalability': 1,
#                       'comparisons': 1,
#                       'equip': 1,
#                       'regularized': 1,
#                       'average': 1,
#                       'noise': 1,
#                       'identifying': 1,
#                       'actions': 1,
#                       'estimation': 1,
#                       'pairwise': 1,
#                       'hyperlinks': 1,
#                       'deformation': 1,
#                       'terms': 1,
#                       'application': 1,
#                       'true': 1,
#                       'caveats': 1,
#                       'civilian': 1,
#                       'self': 1,
#                       'expected': 1,
#                       'combinatorial': 1,
#                       'agreement': 1,
#                       'elman': 1,
#                       'selecting': 1,
#                       'another': 1,
#                       'consolidated': 1,
#                       'instances': 1,
#                       'map': 1,
#                       'required': 1,
#                       'spectrum': 1,
#                       'grammars': 1,
#                       'adjuncts': 1,
#                       'incrementality': 1,
#                       'weighted': 1,
#                       'companies': 1,
#                       'visualising': 1,
#                       'creating': 1,
#                       'process': 1,
#                       'dictionaries': 1,
#                       'simple': 1,
#                       'context': 1,
#                       'increase': 1,
#                       '78': 1,
#                       'complete': 1,
#                       'subword': 1,
#                       'multilingual': 1,
#                       'rhythmic': 1,
#                       'continuing': 1,
#                       'compared': 1,
#                       'copying': 1,
#                       'wikipedia': 1,
#                       'lexicalized': 1,
#                       'highlight': 1,
#                       'words': 1,
#                       'annotation': 1,
#                       'geography': 1,
#                       'syntactic': 1,
#                       'left': 1,
#                       'log': 1,
#                       'discussion': 1,
#                       'keyphrases': 1,
#                       'comprised': 1,
#                       'annotated': 1,
#                       'consideration': 1,
#                       'money': 1,
#                       'wrappers': 1,
#                       'full': 1,
#                       'accompanying': 1,
#                       'universal': 1,
#                       'morphological': 1,
#                       'biomedical': 1,
#                       'expression': 1,
#                       'highway': 1,
#                       'indexing': 1,
#                       'ease': 1,
#                       'customers': 1,
#                       'weighting': 1,
#                       'independence': 1,
#                       'governmental': 1,
#                       'additive': 1,
#                       'gigaword': 1,
#                       'push': 1,
#                       'allowing': 1,
#                       'bidirectional': 1,
#                       'english': 1,
#                       'separate': 1,
#                       'benchmarks': 1,
#                       'paraphrase': 1,
#                       'orderings': 1,
#                       'obdds': 1,
#                       'partially': 1,
#                       'recognize': 1,
#                       'fuzzy': 1,
#                       'contradictory': 1,
#                       'dynamic': 1,
#                       'careful': 1,
#                       'routing': 1,
#                       'admissible': 1,
#                       'dewey': 1,
#                       'membership': 1,
#                       'aux': 1,
#                       'modified': 1,
#                       'gaussian': 1,
#                       'inferring': 1,
#                       'consistency': 1,
#                       'expiring': 1,
#                       'promise': 1,
#                       'polytrees': 1,
#                       'indeterminacy': 1,
#                       'reasoning': 1,
#                       'optimize': 1,
#                       'crisp': 1,
#                       'substantial': 1,
#                       'into': 1,
#                       'exploitation': 1,
#                       'denoising': 1,
#                       'supporting': 1,
#                       'recursive': 1,
#                       'suggestions': 1,
#                       'prioritized': 1,
#                       'take': 1,
#                       'unspecified': 1,
#                       'ga': 1,
#                       'diagnoses': 1,
#                       'business': 1,
#                       'loosely': 1,
#                       'artificial': 1,
#                       'inspiring': 1,
#                       'allow': 1,
#                       'criticism': 1,
#                       'intervention': 1,
#                       'obfuscate': 1,
#                       'exercising': 1,
#                       'mitigate': 1,
#                       'preference': 1,
#                       'types': 1,
#                       'hypothetical': 1,
#                       'procedural': 1,
#                       'distributed': 1,
#                       'representing': 1,
#                       'part': 1,
#                       'development': 1,
#                       'discussed': 1,
#                       'heuristics': 1,
#                       'spectators': 1,
#                       'reasonable': 1,
#                       'q': 1,
#                       'teamwork': 1,
#                       'imple': 1,
#                       'mlp': 1,
#                       'legible': 1,
#                       'texts': 1,
#                       'completely': 1,
#                       'what': 1,
#                       'outlining': 1,
#                       'introducing': 1,
#                       'versus': 1,
#                       'visualization': 1,
#                       'documenting': 1,
#                       'broadening': 1,
#                       'predicting': 1,
#                       'hidden': 1,
#                       'gibb': 1,
#                       'spectrograms': 1,
#                       'neuroimaging': 1,
#                       'neuro': 1,
#                       'coded': 1,
#                       'admitting': 1,
#                       'analogous': 1,
#                       'mixture': 1,
#                       'functional': 1,
#                       'dependence': 1,
#                       'correct': 1,
#                       'via': 1,
#                       'simultaneous': 1,
#                       'increased': 1,
#                       'web': 1,
#                       'capture': 1,
#                       'likely': 1,
#                       'potential': 1,
#                       'improves': 1,
#                       'hints': 1,
#                       'examples': 1,
#                       'compression': 1,
#                       'potentials': 1,
#                       'euclidean': 1,
#                       'eye': 1,
#                       'listening': 1,
#                       'stacks': 1,
#                       'facial': 1,
#                       'production': 1,
#                       'objectively': 1,
#                       'no': 1,
#                       'invariant': 1,
#                       'statistics': 1,
#                       'wavelet': 1,
#                       'research': 1,
#                       'post': 1,
#                       'incorporate': 1,
#                       'inexperienced': 1,
#                       'distinct': 1,
#                       'inputs': 1,
#                       'zones': 1,
#                       'metabolic': 1,
#                       'verification': 1,
#                       'together': 1,
#                       'occlusions': 1,
#                       'articles': 1,
#                       'cluttered': 1,
#                       'distinctive': 1,
#                       'setups': 1,
#                       'resolving': 1,
#                       'benefit': 1,
#                       'areas': 1,
#                       'incorporation': 1,
#                       'fusion': 1,
#                       'theoreticians': 1,
#                       'individual': 1,
#                       'recording': 1,
#                       'straight': 1,
#                       'land': 1,
#                       'quantitatively': 1,
#                       'readability': 1,
#                       'gaze': 1,
#                       'abnormal': 1,
#                       'boost': 1,
#                       'fingerprint': 1,
#                       'visemes': 1,
#                       'symbol': 1,
#                       'scene': 1,
#                       'descriptions': 1,
#                       'baseline': 1,
#                       'work': 1,
#                       'segmentation': 1,
#                       'highly': 1,
#                       'sociology': 1,
#                       'decreasing': 1,
#                       'valuable': 1,
#                       'expressive': 1,
#                       'eliminating': 1,
#                       'shallower': 1,
#                       'benchmarking': 1,
#                       'resnets': 1,
#                       'runtime': 1,
#                       'sequences': 1,
#                       'automatically': 1,
#                       'satisfy': 1,
#                       'car': 1,
#                       'tune': 1,
#                       'delineating': 1,
#                       'uni': 1,
#                       'pathologies': 1,
#                       'tv': 1,
#                       'do': 1,
#                       'insufficient': 1,
#                       'action': 1,
#                       'out': 1,
#                       'speed': 1,
#                       'skeleton': 1,
#                       'during': 1,
#                       'suppress': 1,
#                       'rotated': 1,
#                       'characteristic': 1,
#                       'klt': 1,
#                       'colorization': 1,
#                       'bayesian': 1,
#                       'limiting': 1,
#                       'measurement': 1,
#                       'determination': 1,
#                       'parallel': 1,
#                       'synthetically': 1,
#                       'contain': 1,
#                       'run': 1,
#                       'deepen': 1,
#                       'weather': 1,
#                       'lighting': 1,
#                       'making': 1,
#                       'applying': 1,
#                       'less': 1,
#                       'combining': 1,
#                       'overfitting': 1,
#                       'camping': 1,
#                       'almost': 1,
#                       'maintain': 1,
#                       'consistent': 1,
#                       'increasing': 1,
#                       'software': 1,
#                       'pictures': 1,
#                       'augmented': 1,
#                       'quantitate': 1,
#                       'viewed': 1,
#                       'slight': 1,
#                       'spatially': 1,
#                       'recently': 1,
#                       'imperceptibility': 1,
#                       'shares': 1,
#                       'release': 1,
#                       'lstm': 1,
#                       'controlled': 1,
#                       'intra': 1,
#                       'bounding': 1,
#                       'few': 1,
#                       '18': 1,
#                       'explaining': 1,
#                       'brodmann': 1,
#                       'physiological': 1,
#                       'publicly': 1,
#                       'analyze': 1,
#                       'carefully': 1,
#                       'temporally': 1,
#                       'behavioural': 1,
#                       'coping': 1,
#                       'leveraging': 1,
#                       'reliable': 1,
#                       'commercial': 1,
#                       'considerable': 1,
#                       'procedure': 1,
#                       'normal': 1,
#                       'subspaces': 1,
#                       'age': 1,
#                       'public': 1,
#                       'characterize': 1,
#                       'shift': 1,
#                       'curved': 1,
#                       'autonomous': 1,
#                       'rcnn': 1,
#                       'synthesized': 1,
#                       'significantly': 1,
#                       'attention': 1,
#                       'inaccuracies': 1,
#                       'subtasks': 1,
#                       'properties': 1,
#                       'striding': 1,
#                       'revealed': 1,
#                       '-': 1,
#                       'topographic': 1,
#                       'svm': 1,
#                       'r': 1,
#                       'fisher': 1,
#                       'gases': 1,
#                       'online': 1,
#                       'error': 1,
#                       'relevance': 1,
#                       'renewed': 1,
#                       'discontinuous': 1,
#                       'lasso': 1,
#                       'labeling': 1,
#                       'protein': 1,
#                       'polynomial': 1,
#                       'nearest': 1,
#                       'code': 1,
#                       'user': 1,
#                       'reinforcement': 1,
#                       'alternatives': 1,
#                       'soliton': 1,
#                       'rank': 1,
#                       'art': 1,
#                       'nurse': 1,
#                       'outreach': 1,
#                       'difficulty': 1,
#                       'applied': 1,
#                       'episodic': 1,
#                       'binary': 1,
#                       'broad': 1,
#                       '40': 1,
#                       'constrained': 1,
#                       'weight': 1,
#                       'dedicated': 1,
#                       'selection': 1,
#                       'recognizable': 1,
#                       'than': 1,
#                       'sentiment': 1,
#                       'sindhi': 1,
#                       '177': 1,
#                       'names': 1,
#                       'opinions': 1,
#                       'ill': 1,
#                       'recall': 1,
#                       'bigger': 1,
#                       'proposed': 1,
#                       'successful': 1,
#                       'processes': 1,
#                       'multicore': 1,
#                       'leijnse': 1,
#                       'climbing': 1,
#                       'crystals': 1,
#                       'hybrid': 1,
#                       'explorations': 1,
#                       'assist': 1,
#                       'logic': 1,
#                       'certain': 1,
#                       'others': 1,
#                       'complexity': 1,
#                       'fission': 1,
#                       'maintenance': 1,
#                       'meta': 1,
#                       'feedback': 1,
#                       'checks': 1,
#                       'overlapping': 1,
#                       'finitely': 1,
#                       'actual': 1,
#                       'unit': 1,
#                       'technological': 1,
#                       'used': 1,
#                       'specialized': 1,
#                       'extending': 1,
#                       'problem': 1,
#                       'taylor': 1,
#                       'robots': 1,
#                       'fragments': 1,
#                       'goals': 1,
#                       'johnsons': 1,
#                       'attracts': 1,
#                       'achieved': 1,
#                       'mechanisms': 1,
#                       'divergences': 1,
#                       'performing': 1,
#                       'evolving': 1,
#                       ...}),
#              ...})

# %%
class LaplaceLanguageModel(NGramLanguageModel): 
    """ this code is an example, no need to change anything """
    def __init__(self, lines, n, delta=1.0):
        self.n = n
        counts = count_ngrams(lines, self.n)
        self.vocab = set(token for token_counts in counts.values() for token in token_counts)
        self.probs = defaultdict(Counter)

        for prefix in counts:
            token_counts = counts[prefix]
            total_count = sum(token_counts.values()) + delta * len(self.vocab)
            self.probs[prefix] = {token: (token_counts[token] + delta) / total_count
                                          for token in token_counts}
    def get_possible_next_tokens(self, prefix):
        token_probs = super().get_possible_next_tokens(prefix)
        missing_prob_total = 1.0 - sum(token_probs.values())
        missing_prob = missing_prob_total / max(1, len(self.vocab) - len(token_probs))
        return {token: token_probs.get(token, missing_prob) for token in self.vocab}
    
    def get_next_token_prob(self, prefix, next_token):
        token_probs = super().get_possible_next_tokens(prefix)
        if next_token in token_probs:
            return token_probs[next_token]
        else:
            missing_prob_total = 1.0 - sum(token_probs.values())
            missing_prob_total = max(0, missing_prob_total) # prevent rounding errors
            return missing_prob_total / max(1, len(self.vocab) - len(token_probs))

# %% [markdown]
# **Disclaimer**: the implementation above assumes all words unknown within a given context to be equally likely, *as well as the words outside of vocabulary*. Therefore, its' perplexity will be lower than it should when encountering such words. Therefore, comparing it with a model with fewer unknown words will not be fair. When implementing your own smoothing, you may handle this by adding a virtual `UNK` token of non-zero probability. Technically, this will result in a model where probabilities do not add up to $1$, but it is close enough for a practice excercise.

# %%
#test that it's a valid probability model
for n in (1, 2, 3):
    dummy_lm = LaplaceLanguageModel(dummy_lines, n=n)
    assert np.allclose(sum([dummy_lm.get_next_token_prob('a', w_i) for w_i in dummy_lm.vocab]), 1), "I told you not to break anything! :)"
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 29806.03it/s]
# 100%|██████████| 100/100 [00:00<00:00, 64488.07it/s]
# 100%|██████████| 100/100 [00:00<00:00, 21353.75it/s]

# %%
for n in (1, 2, 3):
    lm = LaplaceLanguageModel(train_lines, n=n, delta=0.1)
    ppx = perplexity(lm, test_lines)
    print("N = %i, Perplexity = %.5f" % (n, ppx))
# Out:
# 100%|██████████| 30750/30750 [00:01<00:00, 20350.17it/s]
# /var/folders/zm/dkxvs8l50z3g4ygcywqr67qr0000gn/T/ipykernel_8857/1299495968.py:16: RuntimeWarning: divide by zero encountered in log
#   prob = max(np.log(prob), min_logprob)
# N = 1, Perplexity = 1832.66878
# 100%|██████████| 30750/30750 [00:02<00:00, 12347.92it/s]
# N = 2, Perplexity = 470.48021
# 100%|██████████| 30750/30750 [00:05<00:00, 5988.33it/s]
# N = 3, Perplexity = 3679.44765

# %%
# optional: try to sample tokens from such a model

# %% [markdown]
# ### Kneser-Ney smoothing (2 points)
#
# Additive smoothing is simple, reasonably good but definitely not a State of The Art algorithm.
#
#
# Your final task in this notebook is to implement [Kneser-Ney](https://en.wikipedia.org/wiki/Kneser%E2%80%93Ney_smoothing) smoothing.
#
# It can be computed recurrently, for n>1:
#
# $$P_{kn}(w_t | prefix_{n-1}) = { \max(0, Count(prefix_{n-1}, w_t) - \delta) \over \sum_{\hat w} Count(prefix_{n-1}, \hat w)} + \lambda_{prefix_{n-1}} \cdot P_{kn}(w_t | prefix_{n-2})$$
#
# where
# - $prefix_{n-1}$ is a tuple of {n-1} previous tokens
# - $lambda_{prefix_{n-1}}$ is a normalization constant chosen so that probabilities add up to 1
# - Unigram $P_{kn}(w_t | prefix_{n-2})$ corresponds to Kneser Ney smoothing for {N-1}-gram language model.
# - Unigram $P_{kn}(w_t)$ is a special case: how likely it is to see x_t in an unfamiliar context
#
# See lecture slides or wiki for more detailed formulae.
#
# __Your task__ is to
# - implement `KneserNeyLanguageModel` class,
# - test it on 1-3 gram language models
# - find optimal (within reason) smoothing delta for 3-gram language model with Kneser-Ney smoothing

# %%
count_ngrams(dummy_lines, n=2)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 6324.82it/s]
# defaultdict(collections.Counter,
#             {('_UNK_',): Counter({'a': 13,
#                       'the': 3,
#                       'on': 3,
#                       'using': 2,
#                       'learning': 2,
#                       'automatic': 2,
#                       'why': 2,
#                       'proceedings': 2,
#                       'piecewise': 2,
#                       'differential': 1,
#                       'what': 1,
#                       'p': 1,
#                       'computational': 1,
#                       'weak': 1,
#                       'creating': 1,
#                       'defeasible': 1,
#                       'essence': 1,
#                       'deep': 1,
#                       'statistical': 1,
#                       'complex': 1,
#                       'serious': 1,
#                       'preprocessing': 1,
#                       'liquid': 1,
#                       'mining': 1,
#                       'towards': 1,
#                       'icon': 1,
#                       'recognition': 1,
#                       'glottochronologic': 1,
#                       'utility': 1,
#                       'temporized': 1,
#                       'backpropagation': 1,
#                       'random': 1,
#                       'network': 1,
#                       'glottochronology': 1,
#                       'time': 1,
#                       'convolutional': 1,
#                       'fitness': 1,
#                       'flip': 1,
#                       'autonomous': 1,
#                       'activitynet': 1,
#                       'decision': 1,
#                       'text': 1,
#                       'discrimination': 1,
#                       'are': 1,
#                       'extraction': 1,
#                       'comments': 1,
#                       'resource': 1,
#                       'advances': 1,
#                       'exploration': 1,
#                       'quantified': 1,
#                       'in': 1,
#                       'introduction': 1,
#                       'beyond': 1,
#                       'norm': 1,
#                       'about': 1,
#                       'unary': 1,
#                       'some': 1,
#                       'convex': 1,
#                       'neurocontrol': 1,
#                       'philosophy': 1,
#                       'parallels': 1,
#                       'an': 1,
#                       'calculate': 1,
#                       'group': 1,
#                       'entropy': 1,
#                       'word': 1,
#                       'guarded': 1,
#                       'cornell': 1,
#                       'semistability': 1,
#                       'attack': 1,
#                       'standardization': 1,
#                       'defensive': 1,
#                       'how': 1,
#                       'technical': 1,
#                       'sat': 1,
#                       'approximated': 1,
#                       'solving': 1,
#                       'agent': 1}),
#              ('differential',): Counter({'contrastive': 1}),
#              ('contrastive',): Counter({'divergence': 1}),
#              ('divergence',): Counter({';': 1}),
#              (';',): Counter({'this': 36,
#                       'we': 16,
#                       'in': 10,
#                       'a': 8,
#                       'the': 6,
#                       'introduction': 2,
#                       'short': 1,
#                       'recent': 1,
#                       'an': 1,
#                       'creating': 1,
#                       'major': 1,
#                       'mining': 1,
#                       'matching': 1,
#                       'it': 1,
#                       'i': 1,
#                       '2011': 1,
#                       'comments': 1,
#                       'advances': 1,
#                       'maurice': 1,
#                       'comment': 1,
#                       'section': 1,
#                       'why': 1,
#                       'methods': 1,
#                       'proceedings': 1,
#                       'stock': 1,
#                       'two': 1,
#                       'computer': 1,
#                       'looks': 1}),
#              ('this',): Counter({'paper': 23,
#                       'is': 5,
#                       'article': 5,
#                       'note': 2,
#                       'submission': 2,
#                       'work': 2,
#                       'preprint': 1,
#                       'abstract': 1,
#                       'essay': 1,
#                       'short': 1,
#                       'survey': 1,
#                       'chapter': 1,
#                       'script': 1,
#                       'result': 1,
#                       'sequential': 1,
#                       'manuscript': 1,
#                       'manuscripts': 1}),
#              ('paper',): Counter({'has': 14,
#                       'presents': 3,
#                       'we': 3,
#                       'specifies': 1,
#                       ',': 1,
#                       'describes': 1}),
#              ('has',): Counter({'been': 17}),
#              ('been',): Counter({'withdrawn': 16, 'retracted': 1}),
#              ('retracted',): Counter({'.': 1}),
#              ('.',): Counter({'_EOS_': 81,
#                       'we': 3,
#                       '1': 2,
#                       '0': 2,
#                       'yamada': 2,
#                       '02141': 1,
#                       'this': 1,
#                       'comment': 1,
#                       '3': 1,
#                       'a': 1,
#                       'semantics': 1,
#                       'methods': 1,
#                       'since': 1,
#                       '0225': 1,
#                       '2058': 1,
#                       '2061': 1,
#                       '2270': 1,
#                       'while': 1,
#                       'exposes': 1}),
#              ('what',): Counter({'does': 1}),
#              ('does',): Counter({'artificial': 1, 'not': 1}),
#              ('artificial',): Counter({'intelligence': 3,
#                       'life': 2,
#                       'intlligence': 1}),
#              ('life',): Counter({'tell': 1, 'journal': 1}),
#              ('tell',): Counter({'us': 1}),
#              ('us',): Counter({'about': 1, ',': 1}),
#              ('about',): Counter({'death': 1, 'compression': 1, 'the': 1}),
#              ('death',): Counter({'?': 1}),
#              ('?',): Counter({';': 4}),
#              ('short',): Counter({'philosophical': 1, 'note': 1, 'review': 1}),
#              ('philosophical',): Counter({'essay': 1, 'issues': 1}),
#              ('essay',): Counter({'_EOS_': 1, 'explores': 1}),
#              ('p',): Counter({'=': 2, '=?': 1}),
#              ('=',): Counter({'np': 2}),
#              ('np',): Counter({'-': 2, ';': 1, 'problem': 1, '.': 1}),
#              ('we',): Counter({'show': 5,
#                       'propose': 4,
#                       'use': 3,
#                       'present': 2,
#                       'investigate': 2,
#                       'have': 2,
#                       'claim': 1,
#                       'calculate': 1,
#                       'prove': 1,
#                       'derive': 1,
#                       'mainly': 1,
#                       'cover': 1,
#                       'analyze': 1,
#                       'describe': 1,
#                       'posted': 1,
#                       'briefly': 1,
#                       'study': 1}),
#              ('claim',): Counter({'to': 1}),
#              ('to',): Counter({'the': 8,
#                       'a': 3,
#                       'develop': 2,
#                       'resolve': 1,
#                       'deep': 1,
#                       'be': 1,
#                       'extremely': 1,
#                       'an': 1,
#                       'persian': 1,
#                       'represent': 1,
#                       'make': 1,
#                       'withdraw': 1,
#                       'go': 1,
#                       'extract': 1,
#                       'some': 1,
#                       'his': 1,
#                       'minimize': 1,
#                       'control': 1,
#                       'analyze': 1,
#                       'object': 1,
#                       'calculate': 1,
#                       'understand': 1,
#                       'formal': 1,
#                       'climb': 1,
#                       'determine': 1,
#                       'adversarial': 1,
#                       'targeted': 1,
#                       'realize': 1,
#                       'grant': 1,
#                       'present': 1,
#                       'adjust': 1,
#                       '[': 1,
#                       'see': 1,
#                       'deal': 1}),
#              ('resolve',): Counter({'the': 1}),
#              ('the',): Counter({'author': 10,
#                       'future': 3,
#                       'first': 3,
#                       'existence': 3,
#                       'authors': 2,
#                       'yahoo': 2,
#                       '26th': 2,
#                       'entropy': 2,
#                       'ukrainian': 2,
#                       'law': 2,
#                       'triangle': 2,
#                       'jaccard': 2,
#                       'liver': 2,
#                       'p': 1,
#                       'oscar': 1,
#                       'essence': 1,
#                       'tool': 1,
#                       'special': 1,
#                       'results': 1,
#                       'icon': 1,
#                       'model': 1,
#                       'submission': 1,
#                       'gradient': 1,
#                       'network': 1,
#                       'translation': 1,
#                       'minor': 1,
#                       'use': 1,
#                       'theory': 1,
#                       'outline': 1,
#                       'activitynet': 1,
#                       'probability': 1,
#                       'postscript': 1,
#                       'final': 1,
#                       'slides': 1,
#                       'language': 1,
#                       'limits': 1,
#                       'modeling': 1,
#                       'influence': 1,
#                       '2d': 1,
#                       'preface': 1,
#                       'capacity': 1,
#                       'ideal': 1,
#                       'grapheme': 1,
#                       'cyrillic': 1,
#                       'role': 1,
#                       'interplay': 1,
#                       'universality': 1,
#                       'possibility': 1,
#                       'complete': 1,
#                       'development': 1,
#                       'algorithm': 1,
#                       'corresponding': 1,
#                       'face': 1,
#                       'ai': 1,
#                       'emergence': 1,
#                       'behavior': 1,
#                       'help': 1,
#                       'history': 1,
#                       'term': 1,
#                       'readability': 1,
#                       'experiments': 1,
#                       'logic': 1,
#                       'area': 1,
#                       'method': 1,
#                       'car': 1,
#                       'distance': 1,
#                       'object': 1,
#                       'telugu': 1,
#                       'computation': 1,
#                       'nlpcc': 1,
#                       'cornell': 1,
#                       'previous': 1,
#                       'leaderboards': 1,
#                       'formal': 1,
#                       'act': 1,
#                       'proceedings': 1,
#                       'level': 1,
#                       'best': 1,
#                       'mnist': 1,
#                       'submitter': 1,
#                       'legal': 1,
#                       'license': 1,
#                       'work': 1,
#                       'completeness': 1,
#                       'higher': 1,
#                       'primary': 1,
#                       'coefficient': 1,
#                       'proofs': 1,
#                       'aim': 1,
#                       'image': 1,
#                       'connection': 1,
#                       'epipolar': 1,
#                       'nearest': 1,
#                       'syntax': 1}),
#              ('=?',): Counter({'np': 1}),
#              ('problem',): Counter({'via': 1, 'by': 1, '.': 1}),
#              ('via',): Counter({'a': 1, '2d': 1, 'leave': 1}),
#              ('a',): Counter({'new': 7,
#                       'note': 3,
#                       'modular': 2,
#                       'description': 2,
#                       'graph': 2,
#                       'notation': 2,
#                       'crucial': 2,
#                       'method': 2,
#                       'machine': 2,
#                       'general': 2,
#                       'gravitational': 2,
#                       'survey': 2,
#                       'projective': 2,
#                       'formal': 1,
#                       'system': 1,
#                       'brief': 1,
#                       '*': 1,
#                       'step': 1,
#                       'hierarchical': 1,
#                       'glottochronologic': 1,
#                       'deep': 1,
#                       'representation': 1,
#                       'comment': 1,
#                       ')': 1,
#                       'duplicate': 1,
#                       'theory': 1,
#                       'technique': 1,
#                       'major': 1,
#                       'semantic': 1,
#                       'great': 1,
#                       'pioneer': 1,
#                       'rewritten': 1,
#                       '(': 1,
#                       'human': 1,
#                       'neural': 1,
#                       'dna': 1,
#                       'few': 1,
#                       'short': 1,
#                       'history': 1,
#                       'long': 1,
#                       'tutorial': 1,
#                       'course': 1,
#                       'variant': 1,
#                       'learning': 1,
#                       'presentation': 1,
#                       'company': 1,
#                       'financial': 1,
#                       'sense': 1,
#                       '"': 1,
#                       'realistic': 1,
#                       'multilayer': 1,
#                       'tool': 1,
#                       'remark': 1,
#                       'prominent': 1,
#                       'game': 1,
#                       'funny': 1,
#                       'playful': 1,
#                       'primal': 1,
#                       'priori': 1,
#                       'fundamental': 1,
#                       'primer': 1,
#                       'introduction': 1,
#                       'latent': 1}),
#              ('formal',): Counter({'representation': 2,
#                       'argument': 1,
#                       'concepts': 1}),
#              ('argument',): Counter({'for': 1}),
#              ('for',): Counter({'the': 6,
#                       'a': 3,
#                       'trees': 2,
#                       'markov': 2,
#                       'measuring': 2,
#                       'p': 1,
#                       'natural': 1,
#                       'general': 1,
#                       'faster': 1,
#                       'revision': 1,
#                       'dynamic': 1,
#                       'graphs': 1,
#                       'almost': 1,
#                       'design': 1,
#                       'manufacturability': 1,
#                       'one': 1,
#                       'plagiarism': 1,
#                       'neural': 1,
#                       'biological': 1,
#                       'data': 1,
#                       'students': 1,
#                       'answer': 1,
#                       'stable': 1,
#                       'mapping': 1,
#                       'paracontracting': 1,
#                       'evaluation': 1,
#                       'nlp': 1,
#                       'stock': 1,
#                       'more': 1,
#                       'an': 1,
#                       'pedagogical': 1,
#                       'using': 1,
#                       'learning': 1,
#                       '"': 1,
#                       'approximated': 1,
#                       'automatic': 1}),
#              ('computational',): Counter({'geometry': 1}),
#              ('geometry',): Counter({'column': 1}),
#              ('column',): Counter({'38': 1}),
#              ('38',): Counter({';': 1}),
#              ('recent',): Counter({'results': 1, 'standardisation': 1}),
#              ('results',): Counter({'of': 2,
#                       'on': 1,
#                       'and': 1,
#                       'out': 1,
#                       'we': 1}),
#              ('on',): Counter({'the': 8,
#                       '"': 3,
#                       'logic': 3,
#                       'algorithm': 2,
#                       'compromise': 2,
#                       'micro': 2,
#                       'deep': 2,
#                       'a': 2,
#                       'interpretable': 2,
#                       'curve': 1,
#                       'complex': 1,
#                       'time': 1,
#                       'darwiche': 1,
#                       'graphs': 1,
#                       'argumentation': 1,
#                       'communications': 1,
#                       'calculability': 1,
#                       '``': 1,
#                       'contextual': 1,
#                       'programming': 1,
#                       'word': 1,
#                       'december': 1,
#                       'higher': 1,
#                       'adjusting': 1,
#                       'answer': 1,
#                       'which': 1}),
#              ('curve',): Counter({'reconstruction': 1}),
#              ('reconstruction',): Counter({';': 2, 'are': 1, 'and': 1}),
#              ('are',): Counter({'described': 2,
#                       'efficiently': 1,
#                       'minds': 1,
#                       'fragments': 1,
#                       'considered': 1,
#                       'discussed': 1,
#                       'given': 1,
#                       'available': 1}),
#              ('described',): Counter({'.': 1, ',': 1}),
#              ('weak',): Counter({'evolvability': 1}),
#              ('evolvability',): Counter({'equals': 1, ';': 1}),
#              ('equals',): Counter({'strong': 1}),
#              ('strong',): Counter({'evolvability': 1}),
#              ('an',): Counter({'updated': 1,
#                       'error': 1,
#                       'interesting': 1,
#                       'energy': 1,
#                       'investigation': 1,
#                       'introduction': 1,
#                       'mlp': 1,
#                       'handout': 1,
#                       'agent': 1,
#                       'example': 1}),
#              ('updated',): Counter({'version': 1}),
#              ('version',): Counter({'will': 2, 'of': 2, '1': 1}),
#              ('will',): Counter({'be': 4}),
#              ('be',): Counter({'uploaded': 1,
#                       'np': 1,
#                       'modified': 1,
#                       'used': 1,
#                       'removed': 1,
#                       'posted': 1,
#                       'accurately': 1}),
#              ('uploaded',): Counter({'later': 1}),
#              ('later',): Counter({'.': 1}),
#              ('creating',): Counter({'a': 2}),
#              ('new',): Counter({'ontology': 2,
#                       'combination': 2,
#                       'theory': 1,
#                       'bengali': 1,
#                       'type': 1,
#                       'search': 1,
#                       'mutation': 1}),
#              ('ontology',): Counter({':': 2}),
#              (':',): Counter({'a': 6,
#                       'proof': 1,
#                       'results': 1,
#                       '1612': 1,
#                       'cornell': 1,
#                       '1306': 1,
#                       'an': 1,
#                       'it': 1,
#                       '0711': 1}),
#              ('modular',): Counter({'approach': 2}),
#              ('approach',): Counter({';': 1, '_EOS_': 1, 'extrue': 1}),
#              ('defeasible',): Counter({'reasoning': 1, 'reasoner': 1}),
#              ('reasoning',): Counter({'in': 1}),
#              ('in',): Counter({'this': 10,
#                       'the': 7,
#                       'a': 3,
#                       'computer': 3,
#                       'matrix': 2,
#                       'artificial': 2,
#                       'oscar': 1,
#                       'korf': 1,
#                       'automating': 1,
#                       'adbiatic': 1,
#                       'satelite': 1,
#                       'music': 1,
#                       'simulations': 1,
#                       'multiuser': 1,
#                       'eq': 1,
#                       'spoken': 1,
#                       'our': 1,
#                       'classical': 1,
#                       'memoriam': 1,
#                       'natural': 1,
#                       'homage': 1,
#                       'neural': 1,
#                       'ukrainian': 1,
#                       'five': 1,
#                       'wireless': 1,
#                       'equation': 1,
#                       'its': 1,
#                       'long': 1,
#                       'violation': 1,
#                       'terms': 1,
#                       'computers': 1,
#                       'ct': 1,
#                       'pomdp': 1}),
#              ('oscar',): Counter({';': 1, 'defeasible': 1}),
#              ('is',): Counter({'a': 4,
#                       'not': 4,
#                       'the': 3,
#                       'shown': 2,
#                       'proposed': 2,
#                       'no': 2,
#                       'presented': 2,
#                       'to': 2,
#                       'np': 1,
#                       'taken': 1,
#                       'demonstrated': 1,
#                       'arxiv': 1,
#                       'written': 1,
#                       'discussed': 1,
#                       'syllabic': 1,
#                       'somewhat': 1,
#                       'complete': 1,
#                       'intentionally': 1,
#                       'in': 1,
#                       'raised': 1}),
#              ('system',): Counter({';': 2,
#                       'description': 1,
#                       'is': 1,
#                       'designed': 1}),
#              ('description',): Counter({'for': 1,
#                       ';': 1,
#                       'of': 1,
#                       'and': 1,
#                       '.': 1}),
#              ('reasoner',): Counter({'.': 1}),
#              ('essence',): Counter({"'": 2}),
#              ("'",): Counter({'s': 2,
#                       'gsa': 2,
#                       'is': 2,
#                       'description': 1,
#                       'language': 1,
#                       'expression': 1}),
#              ('of',): Counter({'the': 23,
#                       'a': 12,
#                       'language': 2,
#                       'probability': 2,
#                       'evidence': 2,
#                       'computer': 2,
#                       'object': 2,
#                       'gravity': 2,
#                       'metaheuristics': 2,
#                       'this': 2,
#                       'nips': 2,
#                       'humour': 2,
#                       'cervical': 1,
#                       'consciousness': 1,
#                       'regular': 1,
#                       'quantum': 1,
#                       'protolanguage': 1,
#                       'languages': 1,
#                       'theorem': 1,
#                       'sets': 1,
#                       'uncertainty': 1,
#                       'defaults': 1,
#                       '[': 1,
#                       'argumentation': 1,
#                       'query': 1,
#                       'underlying': 1,
#                       'experiment': 1,
#                       'scientific': 1,
#                       'turing': 1,
#                       'minds': 1,
#                       'benchmarks': 1,
#                       'mu': 1,
#                       'hol': 1,
#                       '(': 1,
#                       'norm': 1,
#                       'vocabulary': 1,
#                       'unary': 1,
#                       'significance': 1,
#                       'syntax': 1,
#                       'applying': 1,
#                       'online': 1,
#                       'convex': 1,
#                       'making': 1,
#                       'artificial': 1,
#                       'superintelligent': 1,
#                       'human': 1,
#                       'bottlenose': 1,
#                       'similarities': 1,
#                       'quantitative': 1,
#                       'bengali': 1,
#                       'using': 1,
#                       'movement': 1,
#                       'telugu': 1,
#                       'entropy': 1,
#                       'resolution': 1,
#                       'proof': 1,
#                       'logic': 1,
#                       'its': 1,
#                       'lexical': 1,
#                       'dictionary': 1,
#                       'corresponding': 1,
#                       'trying': 1,
#                       'our': 1,
#                       'nonnegative': 1,
#                       'hidden': 1,
#                       'first': 1,
#                       'sat': 1,
#                       'determination': 1,
#                       'answer': 1,
#                       'political': 1,
#                       'emergent': 1,
#                       'game': 1}),
#              ('language',): Counter({'processing': 3,
#                       'system': 2,
#                       'with': 2,
#                       'in': 2,
#                       'as': 1,
#                       'and': 1,
#                       'texts': 1,
#                       'to': 1}),
#              ('as',): Counter({'a': 3,
#                       'an': 2,
#                       'used': 1,
#                       'well': 1,
#                       'location': 1}),
#              ('used',): Counter({'by': 1, 'to': 1, 'in': 1, 'for': 1}),
#              ('by',): Counter({'the': 13,
#                       'k': 2,
#                       'cong': 2,
#                       'arxiv': 2,
#                       'dana': 1,
#                       'hooking': 1,
#                       'marker': 1,
#                       'learning': 1}),
#              ('tool',): Counter({'savile': 1, 'for': 1}),
#              ('savile',): Counter({'row': 1}),
#              ('row',): Counter({'.': 1}),
#              ('deep',): Counter({'neural': 2,
#                       'learning': 2,
#                       'methodological': 1,
#                       'networks': 1}),
#              ('neural',): Counter({'networks': 6, 'network': 4}),
#              ('networks',): Counter({';': 3,
#                       '.': 3,
#                       '"': 2,
#                       '-': 1,
#                       'and': 1,
#                       ',': 1,
#                       'to': 1,
#                       'using': 1}),
#              ('-',): Counter({'resolution': 3,
#                       'complete': 2,
#                       'dual': 2,
#                       'shot': 2,
#                       'based': 2,
#                       'blog': 2,
#                       'validation': 2,
#                       'a': 1,
#                       'probability': 1,
#                       'svd': 1,
#                       'flop': 1,
#                       '94': 1,
#                       'learning': 1,
#                       'ofdm': 1,
#                       'order': 1,
#                       '2001': 1,
#                       'constrained': 1,
#                       'forward': 1,
#                       'einstein': 1,
#                       'oriented': 1,
#                       'phoneme': 1,
#                       'armed': 1,
#                       '18': 1,
#                       'one': 1,
#                       'out': 1,
#                       'passing': 1}),
#              ('brief',): Counter({'history': 1}),
#              ('history',): Counter({'of': 2, ';': 1, '.': 1}),
#              ('introduction',): Counter({'to': 4, 'and': 1}),
#              ('and',): Counter({'their': 2,
#                       'pearl': 2,
#                       'the': 2,
#                       'prolog': 2,
#                       'music': 2,
#                       'body': 1,
#                       'utility': 1,
#                       'lev': 1,
#                       'problems': 1,
#                       'dictionary': 1,
#                       'k': 1,
#                       'challenge': 1,
#                       'annotation': 1,
#                       'latin': 1,
#                       'control': 1,
#                       'practice': 1,
#                       'suggests': 1,
#                       'a': 1,
#                       'characterization': 1,
#                       'instantaneously': 1,
#                       'some': 1,
#                       '2': 1,
#                       'language': 1,
#                       'game': 1,
#                       'schemes': 1,
#                       'disadvantages': 1,
#                       'related': 1,
#                       'adversarial': 1,
#                       'regret': 1,
#                       'humans': 1,
#                       'information': 1,
#                       'ending': 1,
#                       'global': 1,
#                       'orbit': 1,
#                       'not': 1,
#                       'heterogeneous': 1,
#                       'show': 1,
#                       'inference': 1,
#                       'case': 1,
#                       'formats': 1,
#                       'discussed': 1,
#                       'dropout': 1,
#                       'demonstrate': 1,
#                       'shape': 1,
#                       'propose': 1,
#                       'semantics': 1}),
#              ('their',): Counter({'history': 1,
#                       'meaning': 1,
#                       'advantages': 1}),
#              ('statistical',): Counter({'physics': 1}),
#              ('physics',): Counter({'for': 1}),
#              ('natural',): Counter({'language': 3}),
#              ('processing',): Counter({';': 2, '.': 1}),
#              ('withdrawn',): Counter({'by': 12, '.': 2, '_EOS_': 1, 'due': 1}),
#              ('author',): Counter({'due': 4,
#                       'ali': 2,
#                       '.': 1,
#                       'because': 1,
#                       'for': 1,
#                       'uses': 1}),
#              ('complex',): Counter({'networks': 4}),
#              ('special',): Counter({'issue': 3}),
#              ('issue',): Counter({'on': 1, ';': 1, '_EOS_': 1}),
#              (',',): Counter({'and': 5,
#                       'we': 3,
#                       'may': 2,
#                       '2017': 2,
#                       '0711': 2,
#                       'artificial': 1,
#                       'intelligence': 1,
#                       'mind': 1,
#                       'not': 1,
#                       'v': 1,
#                       'version': 1,
#                       'computing': 1,
#                       'mainly': 1,
#                       'convexity': 1,
#                       'philosophy': 1,
#                       'their': 1,
#                       'mirror': 1,
#                       'i': 1,
#                       'starting': 1,
#                       'using': 1,
#                       'to': 1,
#                       'group': 1,
#                       'evolutionary': 1,
#                       'action': 1,
#                       'the': 1,
#                       'joint': 1,
#                       'anchorage': 1,
#                       'us': 1,
#                       'held': 1,
#                       'california': 1,
#                       'usa': 1,
#                       'which': 1,
#                       'monotone': 1,
#                       'submodular': 1,
#                       'it': 1,
#                       'such': 1}),
#              ('journal',): Counter({'.': 1}),
#              ('serious',): Counter({'flaws': 1}),
#              ('flaws',): Counter({'in': 1}),
#              ('korf',): Counter({'et': 1}),
#              ('et',): Counter({'al': 1}),
#              ('al',): Counter({".'": 1}),
#              (".'",): Counter({'s': 1}),
#              ('s',): Counter({'analysis': 1,
#                       'postulates': 1,
#                       'assumption': 1}),
#              ('analysis',): Counter({'for': 2, ';': 2, 'on': 1, 'tools': 1}),
#              ('time',): Counter({'complexity': 1, 'hopping': 1, 'in': 1}),
#              ('complexity',): Counter({'of': 1}),
#              ('*',): Counter({';': 1}),
#              ('preprocessing',): Counter({':': 1}),
#              ('step',): Counter({'in': 1}),
#              ('automating',): Counter({'early': 1}),
#              ('early',): Counter({'detection': 1}),
#              ('detection',): Counter({'of': 1, 'tools': 1}),
#              ('cervical',): Counter({'cancer': 1}),
#              ('cancer',): Counter({';': 1}),
#              ('liquid',): Counter({'state': 1}),
#              ('state',): Counter({'interactions': 2,
#                       'machines': 1,
#                       'information': 1}),
#              ('machines',): Counter({'in': 1, 'concerning': 1}),
#              ('adbiatic',): Counter({'quantum': 1}),
#              ('quantum',): Counter({'computers': 1,
#                       'evolution': 1,
#                       'computing': 1}),
#              ('computers',): Counter({'for': 1, '?': 1}),
#              ('general',): Counter({'computation': 1,
#                       'family': 1,
#                       'class': 1}),
#              ('computation',): Counter({';': 1, 'of': 1}),
#              ('major',): Counter({'mistakes': 1, 'rewriting': 1}),
#              ('mistakes',): Counter({'do': 1}),
#              ('do',): Counter({'not': 1}),
#              ('not',): Counter({'genuinely': 2,
#                       'read': 1,
#                       'noticed': 1,
#                       'alphabetic': 1,
#                       'robust': 1,
#                       'secure': 1,
#                       'have': 1,
#                       'apply': 1}),
#              ('read',): Counter({'_EOS_': 1}),
#              ('mining',): Counter({'for': 2}),
#              ('trees',): Counter({'in': 2, 'construction': 1}),
#              ('graph',): Counter({'is': 2}),
#              ('complete',): Counter({';': 1, '.': 1, 'computer': 1, 'for': 1}),
#              ('shown',): Counter({'to': 1, 'that': 1}),
#              ('towards',): Counter({'a': 1}),
#              ('hierarchical',): Counter({'model': 1}),
#              ('model',): Counter({'of': 4, 'for': 1}),
#              ('consciousness',): Counter({',': 1}),
#              ('intelligence',): Counter({'require': 2, ',': 1, ';': 1}),
#              ('mind',): Counter({'and': 1}),
#              ('body',): Counter({';': 1}),
#              ('article',): Counter({'is': 2, 'aims': 1, ',': 1, 'has': 1}),
#              ('taken',): Counter({'out': 1}),
#              ('out',): Counter({'.': 1, 'of': 1, 'cross': 1}),
#              ('notation',): Counter({'for': 2, ';': 1, '.': 1}),
#              ('markov',): Counter({'decision': 2}),
#              ('decision',): Counter({'processes': 2, 'under': 1}),
#              ('processes',): Counter({';': 1, '.': 1, 'where': 1}),
#              ('specifies',): Counter({'a': 1}),
#              ('icon',): Counter({'challenge': 2}),
#              ('challenge',): Counter({'on': 2, '2017': 2, 'participants': 1}),
#              ('algorithm',): Counter({"'": 3,
#                       'selection': 2,
#                       'of': 1,
#                       '.': 1,
#                       'for': 1}),
#              ('selection',): Counter({';': 1, '.': 1}),
#              ('present',): Counter({'the': 1, 'our': 1, 'propositional': 1}),
#              ('recognition',): Counter({'from': 2,
#                       'of': 1,
#                       ';': 1,
#                       'challenge': 1,
#                       '.': 1}),
#              ('regular',): Counter({'shapes': 1}),
#              ('shapes',): Counter({'in': 1}),
#              ('satelite',): Counter({'images': 1}),
#              ('images',): Counter({';': 2}),
#              ('ali',): Counter({'pourmohammad': 2}),
#              ('pourmohammad',): Counter({'.': 2}),
#              ('glottochronologic',): Counter({'retrognostic': 2}),
#              ('retrognostic',): Counter({'of': 2}),
#              ('proposed',): Counter({'_EOS_': 1, '.': 1, 'methods': 1}),
#              ('evolution',): Counter({';': 2}),
#              ('due',): Counter({'to': 6}),
#              ('extremely',): Counter({'unscientific': 1}),
#              ('unscientific',): Counter({'errors': 1}),
#              ('errors',): Counter({'.': 2}),
#              ('utility',): Counter({'-': 1, 'functions': 1}),
#              ('probability',): Counter({'measures': 2,
#                       'duality': 1,
#                       'distributions': 1,
#                       'function': 1}),
#              ('duality',): Counter({';': 1, 'between': 1}),
#              ('presents',): Counter({'duality': 1, 'some': 1, 'an': 1}),
#              ('between',): Counter({'probability': 1,
#                       'arabic': 1,
#                       'logic': 1,
#                       'dolphins': 1,
#                       'the': 1}),
#              ('distributions',): Counter({'and': 1}),
#              ('functions',): Counter({'.': 1, 'for': 1, 'are': 1}),
#              ('temporized',): Counter({'equilibria': 1}),
#              ('equilibria',): Counter({';': 1}),
#              ('crucial',): Counter({'error': 1, 'sign': 1}),
#              ('error',): Counter({'in': 3, 'found': 1}),
#              ('submission',): Counter({'action': 1,
#                       'contains': 1,
#                       '(': 1,
#                       'has': 1}),
#              ('action',): Counter({'.': 1, 'and': 1}),
#              ('backpropagation',): Counter({'in': 1}),
#              ('matrix',): Counter({'notation': 2, 'satisfying': 1}),
#              ('note',): Counter({'on': 3, 'we': 2, 'discusses': 1}),
#              ('calculate',): Counter({'the': 2, 'distance': 1}),
#              ('gradient',): Counter({'of': 1}),
#              ('network',): Counter({'function': 1,
#                       'motifs': 1,
#                       'to': 1,
#                       'inspired': 1,
#                       'learning': 1,
#                       'building': 1}),
#              ('function',): Counter({'in': 1, 'that': 1}),
#              ('random',): Counter({'dfas': 1}),
#              ('dfas',): Counter({'are': 1}),
#              ('efficiently',): Counter({'pac': 1}),
#              ('pac',): Counter({'learnable': 1}),
#              ('learnable',): Counter({';': 1}),
#              ('found',): Counter({'by': 1}),
#              ('dana',): Counter({'angluin': 1}),
#              ('angluin',): Counter({'and': 1}),
#              ('lev',): Counter({'reyzin': 1}),
#              ('reyzin',): Counter({'.': 1}),
#              ('motifs',): Counter({'in': 1}),
#              ('music',): Counter({'sequences': 1, ';': 1, ',': 1}),
#              ('sequences',): Counter({';': 1}),
#              ('because',): Counter({'it': 2, 'the': 1}),
#              ('it',): Counter({'is': 4,
#                       'needs': 1,
#                       '_EOS_': 1,
#                       'obtains': 1,
#                       'could': 1}),
#              ('needs',): Counter({'a': 1}),
#              ('methodological',): Counter({'revision': 1}),
#              ('revision',): Counter({'.': 1, '_EOS_': 1}),
#              ('glottochronology',): Counter({'and': 1}),
#              ('problems',): Counter({'of': 1, ',': 1, '.': 1}),
#              ('protolanguage',): Counter({'reconstruction': 1}),
#              ('method',): Counter({'of': 2,
#                       'in': 1,
#                       'for': 1,
#                       ';': 1,
#                       'and': 1}),
#              ('languages',): Counter({'genealogical': 1,
#                       ';': 1,
#                       '.': 1,
#                       'for': 1}),
#              ('genealogical',): Counter({'trees': 1}),
#              ('construction',): Counter({'is': 1}),
#              ('using',): Counter({'video': 2,
#                       'slp': 1,
#                       'sets': 1,
#                       'grammatical': 1,
#                       'particle': 1,
#                       'with': 1}),
#              ('slp',): Counter({'neural': 1}),
#              ('persian',): Counter({'handwritten': 1}),
#              ('handwritten',): Counter({'digits': 1}),
#              ('digits',): Counter({'recognition': 1}),
#              ('hopping',): Counter({'technique': 1}),
#              ('technique',): Counter({'for': 1, 'to': 1}),
#              ('faster',): Counter({'reinforcement': 1}),
#              ('reinforcement',): Counter({'learning': 1}),
#              ('learning',): Counter({'and': 4,
#                       ';': 2,
#                       'in': 1,
#                       'framework': 1,
#                       'low': 1,
#                       'problems': 1,
#                       'model': 1,
#                       ',': 1,
#                       'large': 1,
#                       'states': 1,
#                       'a': 1}),
#              ('simulations',): Counter({';': 1}),
#              ('preprint',): Counter({'has': 1}),
#              ('convolutional',): Counter({'matching': 1}),
#              ('matching',): Counter({'pursuit': 2}),
#              ('pursuit',): Counter({'and': 2}),
#              ('dictionary',): Counter({'training': 1, 'models': 1}),
#              ('training',): Counter({';': 1, 'data': 1}),
#              ('k',): Counter({'.': 2, '-': 1}),
#              ('svd',): Counter({'is': 1}),
#              ('demonstrated',): Counter({'in': 1}),
#              ('translation',): Counter({'invariant': 1}),
#              ('invariant',): Counter({'setting': 1}),
#              ('setting',): Counter({'_EOS_': 1}),
#              ('fitness',): Counter({'landscape': 1}),
#              ('landscape',): Counter({'analysis': 1}),
#              ('dynamic',): Counter({'resource': 1}),
#              ('resource',): Counter({'allocation': 2}),
#              ('allocation',): Counter({'in': 1, 'of': 1}),
#              ('multiuser',): Counter({'ofdm': 1}),
#              ('ofdm',): Counter({'based': 2}),
#              ('based',): Counter({'on': 5,
#                       'cognitive': 2,
#                       'capacity': 1,
#                       'convergence': 1,
#                       'ai': 1}),
#              ('cognitive',): Counter({'radio': 2}),
#              ('radio',): Counter({'systems': 2}),
#              ('systems',): Counter({';': 1, 'under': 1}),
#              ('darwiche',): Counter({'and': 2}),
#              ('pearl',): Counter({';': 1, "'": 1}),
#              ('that',): Counter({'it': 2,
#                       'darwiche': 1,
#                       'there': 1,
#                       'should': 1,
#                       'for': 1,
#                       'defensive': 1,
#                       'a': 1,
#                       'selects': 1}),
#              ('postulates',): Counter({'imply': 1}),
#              ('imply',): Counter({'an': 1}),
#              ('interesting',): Counter({'property': 1}),
#              ('property',): Counter({',': 1}),
#              ('noticed',): Counter({'by': 1}),
#              ('authors',): Counter({'.': 1, 'due': 1}),
#              ('flip',): Counter({'-': 1}),
#              ('flop',): Counter({'sublinear': 1}),
#              ('sublinear',): Counter({'models': 2}),
#              ('models',): Counter({'for': 1,
#                       'on': 1,
#                       'and': 1,
#                       ';': 1,
#                       'of': 1}),
#              ('graphs',): Counter({':': 1, '.': 1}),
#              ('proof',): Counter({'of': 1, 'and': 1}),
#              ('theorem',): Counter({'1': 1}),
#              ('1',): Counter({'.': 3, ';': 1, 'will': 1, '_EOS_': 1}),
#              ('prove',): Counter({'that': 1}),
#              ('there',): Counter({'is': 1}),
#              ('no',): Counter({'class': 1, 'more': 1}),
#              ('class',): Counter({'-': 1, 'of': 1}),
#              ('dual',): Counter({'for': 1, 'message': 1}),
#              ('almost',): Counter({'all': 1}),
#              ('all',): Counter({'of': 2, 'sublinear': 1, 'near': 1}),
#              ('autonomous',): Counter({'perceptron': 1}),
#              ('perceptron',): Counter({'neural': 1, ',': 1}),
#              ('inspired',): Counter({'from': 1}),
#              ('from',): Counter({'3d': 2,
#                       'quantum': 1,
#                       'bilingual': 1,
#                       'further': 1,
#                       'an': 1}),
#              ('computing',): Counter({';': 1, 'and': 1}),
#              ('abstract',): Counter({'will': 1}),
#              ('modified',): Counter({'after': 1}),
#              ('after',): Counter({'correcting': 1}),
#              ('correcting',): Counter({'the': 1}),
#              ('minor',): Counter({'error': 1}),
#              ('eq',): Counter({'.(': 1}),
#              ('.(',): Counter({'2': 1}),
#              ('2',): Counter({')': 1, '.': 1, '$': 1, '$)': 1}),
#              (')',): Counter({'_EOS_': 2,
#                       'new': 1,
#                       'quantified': 1,
#                       'was': 1,
#                       'optimal': 1,
#                       'is': 1}),
#              ('sets',): Counter({'of': 2}),
#              ('measures',): Counter({'to': 1, 'as': 1}),
#              ('represent',): Counter({'uncertainty': 1}),
#              ('uncertainty',): Counter({';': 2, '.': 2}),
#              ('i',): Counter({'explore': 1, 'discuss': 1}),
#              ('explore',): Counter({'the': 1}),
#              ('use',): Counter({'of': 2,
#                       'the': 1,
#                       'group': 1,
#                       'rmse': 1,
#                       'marker': 1}),
#              ('representation',): Counter({'of': 4, 'space': 1}),
#              ('comment',): Counter({'on': 3}),
#              ('argumentation',): Counter({';': 1, '.': 1}),
#              ('theory',): Counter({'of': 3, '.': 3, ',': 1}),
#              ('defaults',): Counter({'and': 1}),
#              ('meaning',): Counter({'of': 1, '.': 1}),
#              ('[',): Counter({'gs16': 1, 'arxiv': 1, 'under': 1}),
#              ('gs16',): Counter({']': 1}),
#              (']',): Counter({'to': 1, 'is': 1, 'graduate': 1}),
#              ('develop',): Counter({'(': 1, 'a': 1}),
#              ('(',): Counter({'the': 1,
#                       'ccca': 1,
#                       'original': 1,
#                       'constant': 1,
#                       '1934': 1,
#                       'nearly': 1,
#                       'spf': 1}),
#              ('outline',): Counter({'of': 1}),
#              ('activitynet',): Counter({'challenge': 1, 'large': 1}),
#              ('2017',): Counter({'summary': 2, '_EOS_': 2, 'symposium': 2}),
#              ('summary',): Counter({';': 1, ':': 1}),
#              ('large',): Counter({'scale': 3}),
#              ('scale',): Counter({'activity': 1,
#                       'graphical': 1,
#                       'structured': 1}),
#              ('activity',): Counter({'recognition': 1}),
#              ('participants',): Counter({'papers': 1}),
#              ('papers',): Counter({'.': 1}),
#              ('yahoo',): Counter({'query': 1, 'webscope': 1}),
#              ('query',): Counter({'treebank': 2}),
#              ('treebank',): Counter({',': 2}),
#              ('v',): Counter({'.': 1}),
#              ('0',): Counter({';': 1, ',': 1}),
#              ('annotation',): Counter({'guidelines': 1}),
#              ('guidelines',): Counter({'for': 1}),
#              ('webscope',): Counter({'release': 1}),
#              ('release',): Counter({'of': 1}),
#              ('may',): Counter({'2016': 1, '17': 1, 'be': 1}),
#              ('2016',): Counter({'.': 1, 'shared': 1}),
#              ('under',): Counter({'uncertainty': 1, 'partial': 1, ']': 1}),
#              ('derive',): Counter({'axiomatically': 1}),
#              ('axiomatically',): Counter({'the': 1}),
#              ('should',): Counter({'be': 1}),
#              ('make',): Counter({'decisions': 1}),
#              ('decisions',): Counter({'given': 1}),
#              ('given',): Counter({'any': 1, 'and': 1}),
#              ('any',): Counter({'form': 1, 'training': 1}),
#              ('form',): Counter({'of': 1}),
#              ('underlying',): Counter({'uncertainty': 1}),
#              ('text',): Counter({'analysis': 1}),
#              ('tools',): Counter({'in': 1, 'using': 1}),
#              ('spoken',): Counter({'language': 1}),
#              ('contains',): Counter({'the': 2}),
#              ('postscript',): Counter({'of': 1}),
#              ('final',): Counter({'version': 1}),
#              ('slides',): Counter({'used': 1}),
#              ('our',): Counter({'acl': 1,
#                       'latest': 1,
#                       'system': 1,
#                       'policies': 1}),
# ...
#              ('sensor',): Counter({'networks': 1}),
#              ('particle',): Counter({'swarm': 1}),
#              ('swarm',): Counter({'optimization': 1}),
#              ('optimization',): Counter({';': 3, 'problems': 1}),
#              ('sign',): Counter({'error': 1}),
#              ('equation',): Counter({'1': 1}),
#              ('bengali',): Counter({'readability': 1, 'language': 1}),
#              ('readability',): Counter({'score': 1, 'of': 1}),
#              ('score',): Counter({';': 1}),
#              ('have',): Counter({'proposed': 1, 'got': 1, 'the': 1}),
#              ('texts',): Counter({'.': 2, 'with': 1}),
#              ('got',): Counter({'some': 1}),
#              ('exceptionally',): Counter({'good': 1}),
#              ('good',): Counter({'results': 1}),
#              ('experiments',): Counter({'.': 1}),
#              ('paradigm',): Counter({'and': 1}),
#              ('prolog',): Counter({';': 1, 'appropriate': 1}),
#              ('appropriate',): Counter({'for': 1}),
#              ('course',): Counter({'on': 1}),
#              ('students',): Counter({'familiar': 1, 'taking': 1}),
#              ('familiar',): Counter({'with': 1}),
#              ('imperative',): Counter({'programming': 1}),
#              ('distance',): Counter({'to': 2, ';': 1, 'in': 1}),
#              ('area',): Counter({'where': 1, 'of': 1}),
#              ('where',): Counter({'car': 1, 'only': 1}),
#              ('video',): Counter({'analysis': 1, 'cameras': 1}),
#              ('cameras',): Counter({'installed': 1}),
#              ('installed',): Counter({'on': 1}),
#              ('its',): Counter({'area': 1, 'meaning': 1}),
#              ('movement',): Counter({'.': 1}),
#              ('group',): Counter({'theory': 1, 'actions': 1, ',': 1}),
#              ('actions',): Counter({',': 1}),
#              ('evolutionary',): Counter({'algorithms': 1, 'solve': 1}),
#              ('global',): Counter({'optimization': 1}),
#              ('orbit',): Counter({'to': 1}),
#              ('understand',): Counter({'how': 1}),
#              ('solve',): Counter({'nonconvex': 1}),
#              ('nonconvex',): Counter({'optimization': 1}),
#              ('telugu',): Counter({';': 1, 'script': 1}),
#              ('investigation',): Counter({'of': 1}),
#              ('script',): Counter({'.': 1, 'is': 1}),
#              ('since',): Counter({'this': 1}),
#              ('syllabic',): Counter({',': 1}),
#              ('alphabetic',): Counter({',': 1}),
#              ('somewhat',): Counter({'complicated': 1}),
#              ('complicated',): Counter({'.': 1}),
#              ('word',): Counter({'segmentation': 2}),
#              ('segmentation',): Counter({'on': 2, 'method': 1, 'of': 1}),
#              ('micro',): Counter({'-': 2}),
#              ('blog',): Counter({'texts': 2}),
#              ('external',): Counter({'lexicon': 1}),
#              ('lexicon',): Counter({'and': 1}),
#              ('heterogeneous',): Counter({'data': 1}),
#              ('designed',): Counter({'for': 1}),
#              ('nlpcc',): Counter({'2016': 1}),
#              ('shared',): Counter({'task': 1}),
#              ('task',): Counter({'on': 1}),
#              ('guarded',): Counter({'resolution': 1}),
#              ('resolution',): Counter({'for': 1,
#                       'rule': 1,
#                       'with': 1,
#                       'does': 1,
#                       'approach': 1}),
#              ('answer',): Counter({'set': 3}),
#              ('set',): Counter({'programming': 3}),
#              ('describe',): Counter({'a': 1}),
#              ('variant',): Counter({'of': 1}),
#              ('rule',): Counter({'of': 1}),
#              ('stable',): Counter({'semantics': 1}),
#              ('programs',): Counter({'.': 1}),
#              ('result',): Counter({'.': 1}),
#              ('cornell',): Counter({'semantic': 2, 'spf': 1}),
#              ('spf',): Counter({':': 1, ')': 1}),
#              ('parsing',): Counter({'framework': 2}),
#              ('inference',): Counter({'framework': 1}),
#              ('mapping',): Counter({'natural': 1}),
#              ('semistability',): Counter({'-': 1}),
#              ('convergence',): Counter({'analysis': 1}),
#              ('paracontracting',): Counter({'multiagent': 1}),
#              ('multiagent',): Counter({'coordination': 1}),
#              ('coordination',): Counter({'optimization': 1}),
#              ('sequential',): Counter({'technical': 1, 'processes': 1}),
#              ('technical',): Counter({'report': 2}),
#              ('report',): Counter({'extends': 1, ':': 1}),
#              ('extends',): Counter({'some': 1}),
#              ('previous',): Counter({'results': 1}),
#              ('1306',): Counter({'.': 1}),
#              ('0225',): Counter({'.': 1}),
#              ('proceedings',): Counter({'of': 4}),
#              ('workshop',): Counter({'on': 2}),
#              ('joint',): Counter({'with': 1}),
#              ('ijcnn',): Counter({',': 1}),
#              ('anchorage',): Counter({',': 1}),
#              ('17',): Counter({'-': 1}),
#              ('18',): Counter({',': 1}),
#              ('attack',): Counter({'rmse': 1}),
#              ('rmse',): Counter({'leaderboard': 1, 'for': 1}),
#              ('leaderboard',): Counter({':': 1}),
#              ('case',): Counter({'study': 1}),
#              ('manuscript',): Counter({',': 1}),
#              ('briefly',): Counter({'introduce': 1}),
#              ('introduce',): Counter({'several': 1}),
#              ('several',): Counter({'tricks': 1}),
#              ('tricks',): Counter({'to': 1}),
#              ('climb',): Counter({'the': 1}),
#              ('leaderboards',): Counter({'which': 1}),
#              ('which',): Counter({'use': 1, 'is': 1, 'policies': 1}),
#              ('evaluation',): Counter({'without': 1}),
#              ('without',): Counter({'exploiting': 1}),
#              ('exploiting',): Counter({'any': 1}),
#              ('standardization',): Counter({'of': 1}),
#              ('lexical',): Counter({'information': 1}),
#              ('nlp',): Counter({';': 1}),
#              ('formats',): Counter({'is': 1}),
#              ('well',): Counter({'as': 1}),
#              ('presentation',): Counter({'of': 1}),
#              ('standardisation',): Counter({'activities': 1}),
#              ('activities',): Counter({'.': 1}),
#              ('stock',): Counter({'market': 2, 'or': 1}),
#              ('market',): Counter({'prediction': 2}),
#              ('prediction',): Counter({';': 1, 'is': 1, 'for': 1, '".': 1}),
#              ('act',): Counter({'of': 1}),
#              ('trying',): Counter({'to': 1}),
#              ('determine',): Counter({'the': 1}),
#              ('value',): Counter({'of': 1}),
#              ('company',): Counter({'stock': 1}),
#              ('or',): Counter({'other': 1, 'logic': 1}),
#              ('other',): Counter({'financial': 1}),
#              ('financial',): Counter({'instrument': 1, 'exchange': 1}),
#              ('instrument',): Counter({'traded': 1}),
#              ('traded',): Counter({'on': 1}),
#              ('exchange',): Counter({'.': 1}),
#              ('defensive',): Counter({'distillation': 2}),
#              ('distillation',): Counter({'is': 2}),
#              ('robust',): Counter({'to': 1}),
#              ('examples',): Counter({';': 1}),
#              ('secure',): Counter({':': 1}),
#              ('more',): Counter({'resistant': 1, 'efficient': 1}),
#              ('resistant',): Counter({'to': 1}),
#              ('targeted',): Counter({'misclassification': 1}),
#              ('misclassification',): Counter({'attacks': 1}),
#              ('attacks',): Counter({'than': 1}),
#              ('than',): Counter({'unprotected': 1}),
#              ('unprotected',): Counter({'neural': 1}),
#              ('nips',): Counter({'2017': 2}),
#              ('symposium',): Counter({'on': 2}),
#              ('interpretable',): Counter({'machine': 2}),
#              ('held',): Counter({'in': 1}),
#              ('beach',): Counter({',': 1}),
#              ('california',): Counter({',': 1}),
#              ('usa',): Counter({'on': 1}),
#              ('december',): Counter({'7': 1}),
#              ('7',): Counter({',': 1}),
#              ('piecewise',): Counter({'linear': 2}),
#              ('linear',): Counter({'activation': 1, 'multilayer': 1}),
#              ('activation',): Counter({'functions': 1}),
#              ('administrators',): Counter({'because': 2}),
#              ('intentionally',): Counter({'incomplete': 1}),
#              ('incomplete',): Counter({',': 1}),
#              ('violation',): Counter({'of': 1}),
#              ('policies',): Counter({'.': 1, 'may': 1}),
#              ('triangle',): Counter({'inequality': 2}),
#              ('inequality',): Counter({'for': 2}),
#              ('jaccard',): Counter({'distance': 2}),
#              ('two',): Counter({'simple': 1}),
#              ('simple',): Counter({'proofs': 1}),
#              ('proofs',): Counter({'of': 1, 'for': 1}),
#              ('terms',): Counter({'of': 1}),
#              ('nonnegative',): Counter({',': 1}),
#              ('monotone',): Counter({',': 1}),
#              ('submodular',): Counter({'functions': 1}),
#              ('realize',): Counter({'"': 1}),
#              ('sense',): Counter({'of': 2}),
#              ('humour',): Counter({'"': 2}),
#              ('suggested',): Counter({'previously': 1}),
#              ('previously',): Counter({'[': 1}),
#              ('0711',): Counter({'.': 3}),
#              ('2058',): Counter({',': 1}),
#              ('2061',): Counter({',': 1}),
#              ('2270',): Counter({']': 1}),
#              ('raised',): Counter({'to': 1}),
#              ('level',): Counter({'of': 1}),
#              ('realistic',): Counter({'algorithm': 1}),
#              ('multilayer',): Counter({'perceptrons': 1, 'perceptron': 1}),
#              ('perceptrons',): Counter({'and': 1}),
#              ('dropout',): Counter({';': 1}),
#              ('type',): Counter({'of': 1}),
#              ('hidden',): Counter({'layer': 1}),
#              ('layer',): Counter({'for': 1}),
#              ('demonstrate',): Counter({'that': 1}),
#              ('obtains',): Counter({'the': 1}),
#              ('best',): Counter({'reported': 1}),
#              ('reported',): Counter({'performance': 1}),
#              ('performance',): Counter({'for': 1}),
#              ('mlp',): Counter({'on': 1}),
#              ('mnist',): Counter({'dataset': 1}),
#              ('dataset',): Counter({'.': 1}),
#              ('measuring',): Counter({'prosodic': 1, 'predictive': 1}),
#              ('prosodic',): Counter({'accommodation': 1}),
#              ('accommodation',): Counter({';': 1}),
#              ('submitter',): Counter({'did': 1}),
#              ('did',): Counter({'not': 1}),
#              ('legal',): Counter({'authority': 1}),
#              ('authority',): Counter({'to': 1}),
#              ('grant',): Counter({'the': 1}),
#              ('license',): Counter({'applied': 1}),
#              ('applied',): Counter({'to': 1}),
#              ('remark',): Counter({'on': 1}),
#              ('rue',): Counter({'-': 3}),
#              ('extrue',): Counter({';': 1, '.': 1}),
#              ('prominent',): Counter({'counterexample': 1}),
#              ('counterexample',): Counter({'for': 1}),
#              ('completeness',): Counter({'of': 1}),
#              ('apply',): Counter({'to': 1}),
#              ('sat',): Counter({'as': 1, '.': 1}),
#              ('funny',): Counter({'representation': 1}),
#              ('while',): Counter({'the': 1}),
#              ('primary',): Counter({'interest': 1}),
#              ('interest',): Counter({'is': 1}),
#              ('propositional',): Counter({'satisfiability': 1}),
#              ('satisfiability',): Counter({'in': 1}),
#              ('playful',): Counter({'way': 1}),
#              ('way',): Counter({'for': 1}),
#              ('pedagogical',): Counter({'purposes': 1}),
#              ('purposes',): Counter({',': 1}),
#              ('could',): Counter({'also': 1}),
#              ('also',): Counter({'inspire': 1}),
#              ('inspire',): Counter({'new': 1}),
#              ('heuristics',): Counter({'.': 1}),
#              ('adjusting',): Counter({'$': 1}),
#              ('$',): Counter({'r': 1, 'for': 1}),
#              ('r',): Counter({'^': 2}),
#              ('^',): Counter({'2': 2}),
#              ('cross',): Counter({'-': 2}),
#              ('validation',): Counter({';': 1, '.': 1}),
#              ('adjust',): Counter({'the': 1}),
#              ('coefficient',): Counter({'of': 1}),
#              ('determination',): Counter({'($': 1}),
#              ('($',): Counter({'r': 1}),
#              ('$)',): Counter({'when': 1}),
#              ('when',): Counter({'used': 1}),
#              ('predictive',): Counter({'accuracy': 1}),
#              ('accuracy',): Counter({'via': 1}),
#              ('leave',): Counter({'-': 1}),
#              ('approximated',): Counter({'structured': 1, 'large': 1}),
#              ('structured',): Counter({'prediction': 2}),
#              ('graphical',): Counter({'models': 1}),
#              ('manuscripts',): Counter({'contains': 1}),
#              ('primal',): Counter({'-': 1}),
#              ('message',): Counter({'-': 1}),
#              ('passing',): Counter({'algorithm': 1}),
#              ('".',): Counter({'_EOS_': 1}),
#              ('liver',): Counter({'segmentation': 1, 'based': 1, '.': 1}),
#              ('ct',): Counter({'images': 1}),
#              ('aim',): Counter({'of': 1}),
#              ('priori',): Counter({'knowledge': 1}),
#              ('knowledge',): Counter({'of': 1}),
#              ('image',): Counter({',': 1}),
#              ('such',): Counter({'as': 1}),
#              ('location',): Counter({'and': 1}),
#              ('shape',): Counter({'of': 1}),
#              ('existence',): Counter({'of': 3}),
#              ('projective',): Counter({'reconstruction': 2}),
#              ('connection',): Counter({'between': 1}),
#              ('fundamental',): Counter({'matrix': 1}),
#              ('satisfying',): Counter({'the': 1}),
#              ('epipolar',): Counter({'constraints': 1}),
#              ('constraints',): Counter({'.': 1}),
#              ('solving',): Counter({'traveling': 2}),
#              ('traveling',): Counter({'salesman': 2}),
#              ('salesman',): Counter({'problem': 2}),
#              ('marker',): Counter({'method': 2}),
#              ('mutation',): Counter({'operator': 1}),
#              ('operator',): Counter({'that': 1}),
#              ('selects',): Counter({'the': 1}),
#              ('nearest',): Counter({'neighbor': 1}),
#              ('neighbor',): Counter({'among': 1}),
#              ('among',): Counter({'all': 1}),
#              ('near',): Counter({'neighbors': 1}),
#              ('neighbors',): Counter({'solving': 1}),
#              ('primer',): Counter({'on': 1}),
#              ('intended',): Counter({'as': 1}),
#              ('handout',): Counter({'to': 1}),
#              ('graduate',): Counter({'students': 1}),
#              ('taking',): Counter({'artificial': 1}),
#              ('intlligence',): Counter({'or': 1}),
#              ('classes',): Counter({'.': 1}),
#              ('agent',): Counter({'models': 1, 'based': 1}),
#              ('political',): Counter({'interactions': 1}),
#              ('interactions',): Counter({';': 1, 'from': 1, 'as': 1}),
#              ('looks',): Counter({'at': 1}),
#              ('perspective',): Counter({'to': 1}),
#              ('see',): Counter({'state': 1}),
#              ('example',): Counter({'of': 1}),
#              ('emergent',): Counter({'intelligent': 1}),
#              ('intelligent',): Counter({'behavior': 1}),
#              ('exposes',): Counter({'basic': 1}),
#              ('basic',): Counter({'principles': 1}),
#              ('principles',): Counter({'of': 1}),
#              ('states',): Counter({'representations': 1}),
#              ('pomdp',): Counter({';': 1}),
#              ('deal',): Counter({'with': 1}),
#              ('only',): Counter({'partial': 1}),
#              ('observations',): Counter({'are': 1}),
#              ('available',): Counter({'by': 1}),
#              ('latent',): Counter({'representation': 1}),
#              ('space',): Counter({'on': 1}),
#              ('accurately',): Counter({'learned': 1}),
#              ('learned',): Counter({'.': 1})})

# %%
tuple("12")[1:][1:]
# Out:
# ()

# %%
class KneserNeyLanguageModel(NGramLanguageModel): 
    """ A template for Kneser-Ney language model. Default delta may be suboptimal. """
    def __init__(self, lines, n, delta=1.0):
        assert n >= 1
        self.n = n
        counts = count_ngrams(lines, self.n)
        self.vocab = set(token for token_counts in counts.values() for token in token_counts)
        self.probs = deepcopy(counts)
        if n == 1:
            for _prefix, token_probs in self.probs.items():
                _sum = sum(token_probs.values())
                self.probs[_prefix] = {
                    token: token_count / _sum
                    for token, token_count in token_probs.items()
                }
        else:
            n_minus_1_knlm = KneserNeyLanguageModel(lines, n=n-1, delta=delta)
            for _prefix, token_probs in self.probs.items():
                _sum = sum(token_probs.values())
                _lambda = (1 - sum([max(token_count - delta, 0) / _sum for token_count in token_probs.values()])) / sum([n_minus_1_knlm.get_next_token_prob(" ".join(_prefix[1:]), token) for token in token_probs.keys()])
                self.probs[_prefix] = {
                    token: max(token_count - delta, 0) / _sum + _lambda * n_minus_1_knlm.get_next_token_prob(" ".join(_prefix[1:]), token)
                    for token, token_count in token_probs.items()
                }
        
    def get_possible_next_tokens(self, prefix):
        token_probs = super().get_possible_next_tokens(prefix)
        missing_prob_total = 1.0 - sum(token_probs.values())
        missing_prob = missing_prob_total / max(1, len(self.vocab) - len(token_probs))
        return {token: token_probs.get(token, missing_prob) for token in self.vocab}
        
    def get_next_token_prob(self, prefix, next_token):
        token_probs = super().get_possible_next_tokens(prefix)
        if next_token in token_probs:
            return token_probs[next_token]
        else:
            missing_prob_total = 1.0 - sum(token_probs.values())
            missing_prob_total = max(0, missing_prob_total) # prevent rounding errors
            return missing_prob_total / max(1, len(self.vocab) - len(token_probs))

# %%
#test that it's a valid probability model
for n in (1, 2, 3):
    dummy_lm = KneserNeyLanguageModel(dummy_lines, n=n)
    assert np.allclose(sum([dummy_lm.get_next_token_prob('a', w_i) for w_i in dummy_lm.vocab]), 1), "I told you not to break anything! :)"
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 58710.86it/s]
# 100%|██████████| 100/100 [00:00<00:00, 37065.25it/s]
# 100%|██████████| 100/100 [00:00<00:00, 90336.08it/s]
# 100%|██████████| 100/100 [00:00<00:00, 50171.10it/s]
# 100%|██████████| 100/100 [00:00<00:00, 59944.32it/s]
# 100%|██████████| 100/100 [00:00<00:00, 121503.59it/s]

# %%
for n in (1, 2, 3):
    lm = KneserNeyLanguageModel(train_lines, n=n, delta=0.05)
    ppx = perplexity(lm, test_lines)
    print("N = %i, Perplexity = %.5f" % (n, ppx))
# Out:
# 100%|██████████| 30750/30750 [00:01<00:00, 22645.83it/s]
# /var/folders/zm/dkxvs8l50z3g4ygcywqr67qr0000gn/T/ipykernel_8857/1299495968.py:16: RuntimeWarning: divide by zero encountered in log
#   prob = max(np.log(prob), min_logprob)
# N = 1, Perplexity = 1832.23136
# 100%|██████████| 30750/30750 [00:02<00:00, 11761.79it/s]
# 100%|██████████| 30750/30750 [00:01<00:00, 22348.24it/s]
# N = 2, Perplexity = 30406284.15378
# 100%|██████████| 30750/30750 [00:04<00:00, 6305.74it/s]
# 100%|██████████| 30750/30750 [00:02<00:00, 11961.29it/s]
# 100%|██████████| 30750/30750 [00:01<00:00, 23551.76it/s]
# N = 3, Perplexity = 75105941769898992.00000
